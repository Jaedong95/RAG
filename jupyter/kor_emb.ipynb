# %% [markdown]
# ### 0. Default Setting

# %% [markdown]
# #### Library & Path Setting

# %%
import chromadb
import pandas as pd
import numpy as np 
import os 
import torch
import torch.nn.functional as F
from chromadb.utils import embedding_functions
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer, AutoModel

# %%
default_path = os.getcwd()
data_path = os.path.join(default_path, '../data')

# %% [markdown]
# #### Load data

# %%
data = pd.read_csv(os.path.join(data_path, 'test_data', 'koalphaca_v11.csv'))
print(f'data 개수: {len(data)}')
data.head(3)
# Out:
# data 개수: 21155
#                                             question  \
# 0                   양파는 어떤 식물 부위인가요? 그리고 고구마는 뿌리인가요?
# 1                              스웨터의 유래는 어디에서 시작되었나요?
# 2  토성의 고리가 빛의 띠로 보이는 이유는 무엇인가요?  \n\n토성의 고리는 얼음과 ...
#
#                                               answer
# 0  양파는 잎이 아닌 식물의 줄기 부분입니다. 고구마는 식물의 뿌리 부분입니다. \n\...
# 1  스웨터의 유래는 14세기경 북유럽항구지역에서 어망을 짜던 기술을 의복에 활용하면서 ...
# 2  토성의 고리가 미세한 입자들로 이루어져 있기 때문에, 입자들의 밀도 차이 때문에 카...

# %%
samp = data.sample(5000)
samp.reset_index(inplace=True, drop=True)
samp.head(3)
# Out:
#                                             question  \
# 0  부가가치세 예정신고에 대해 빠르게 알고 싶습니다.\n저는 대학원생이고 오는 25일이...
# 1  최초의 애니메이션은 무엇이었을까요? 그리고 애니메이션 발전의 역사에 대해서도 궁금합니다.
# 2              고주파와 저주파 중 어느 쪽이 덜 들릴까요? 그 이유는 무엇일까요?
#
#                                               answer
# 0  부가가치세 예정신고는 법인일 경우 4월25일과 10월25일에, 개인일 경우 신규사업...
# 1  최초의 애니메이션은 프랑스의 에밀 꼴이 만든 "팡타스마고리(Pantomimes Lu...
# 2  파동은 주파수가 높을수록 산란성이 높아져 멀리 전달되지 못합니다. 따라서 고주파가 ...

# %%
question = samp.question.values.tolist()
question[:2]
# Out:
# ['부가가치세 예정신고에 대해 빠르게 알고 싶습니다.\n저는 대학원생이고 오는 25일이 부가가치세 예정신고일이라고 들었습니다. 일전에 있던 회사에서 세무사에게 모든 것을 대어맡으니 이제부터 막막하네요. 혹시 세무사를 찾아가지 않아도 세금계산서와 도장만 있으면 신고가 가능한 건가요? 그리고 사무실에서 쓰는 전기요금, 임대료, 사무용품 등 경비매출전표와 신용카드매출전표는 어떻게 해야 할까요? 그리고, 왜 예정신고와 확정신고가 있는 건가요?',
#  '최초의 애니메이션은 무엇이었을까요? 그리고 애니메이션 발전의 역사에 대해서도 궁금합니다.']

# %% [markdown]
# ### 1. ChromaDB Setting

# %% [markdown]
# #### Conenct ChromaDB

# %%
chroma_client = chromadb.HttpClient(host='3.39.250.201', port=8000)

# %%
chroma_client.list_collections()
# Out:
# [Collection(name=kor_emb)]

# %% [raw]
# chroma_client.delete_collection("kor_emb")

# %% [markdown]
# #### Create Collection

# %%
# Embedding Function
default_ef = embedding_functions.DefaultEmbeddingFunction()
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="multi-qa-distilbert-dot-v1")

# %% [raw]
# emb_collection = chroma_client.create_collection(name="kor_emb" , embedding_function=default_ef)
# # emb_collection = chroma_client.create_collection(name="kor_emb" , embedding_function=sentence_transformer_ef)

# %%
emb_collection = chroma_client.get_collection(name='kor_emb')

# %%
emb_collection
# Out:
# Collection(name=kor_emb)

# %% [markdown]
# #### Load Model

# %% [raw]
# tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/multi-qa-MiniLM-L6-cos-v1")
# model = AutoModel.from_pretrained("sentence-transformers/multi-qa-MiniLM-L6-cos-v1")

# %%
model = SentenceTransformer("multi-qa-MiniLM-L6-cos-v1")
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %% [raw]
# def mean_pooling(model_output, attention_mask):
#     token_embeddings = model_output.last_hidden_state
#     input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
#     return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# %% [raw]
# def encode(texts):
#     encoded_input = tokenizer(texts, padding=True, truncation=True, return_tensors='pt')
#
#     with torch.no_grad():
#         model_output = model(**encoded_input, return_dict=True)
#
#     embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
#     embeddings = F.normalize(embeddings, p=2, dim=1)
#     return embeddings

# %%
emb = model.encode(question[0])

# %%
np.shape(emb)
# Out:
# (384,)

# %% [raw]
# np.shape(model.encode(samp.question[0])), np.shape(model.encode(question))

# %%
emb = np.array(model.encode(question[0]))
np.shape(emb.reshape(1, -1)) # np.mean(np.array(emb), axis=1)
# Out:
# (1, 384)

# %%
np.mean(emb.reshape(1, -1), axis=1)
# Out:
# array([-0.00252998], dtype=float32)

# %%
doc = []; embeddings = []; metadata = []; ids = []

for idx in range(len(samp)):
    # try:   # token 길이가 특정 값 넘어가면 임베딩 오류 발생   (512 토큰 이상 텍스트 임베딩 불가) 
    emb = model.encode(samp.question[idx])
    # emb = emb.reshape(1, -1) 
    # embedding = np.mean(np.array(emb), axis=1)
    # embedding = embedding.squeeze()
    embeddings.append(list(map(float, emb)))
    # except:
    #    print(idx)
    #    continue 
    doc.append(samp.question[idx])
    ids.append(str(idx + 1))

# %%
np.shape(embeddings), np.shape(doc)
# Out:
# ((5000, 384), (5000,))

# %%
np.shape(embeddings), np.shape(doc), np.shape(ids)
# Out:
# ((5000, 384), (5000,), (5000,))

# %%
emb_collection.add(
    documents=doc,
    embeddings=list(embeddings),
    # metadatas=metadata,
    ids=ids
)

# %%
emb_collection.peek(2)
# Out:
# {'ids': ['1', '10'],
#  'embeddings': [[0.008779450319707394,
#    0.07461600005626678,
#    0.0038231832440942526,
#    -0.037466470152139664,
#    0.019713539630174637,
#    0.0010351758683100343,
#    0.16310028731822968,
#    -0.05064982920885086,
#    0.045647427439689636,
#    -0.014302942901849747,
#    0.1023234874010086,
#    -0.08978056907653809,
#    0.08996978402137756,
#    -0.02701234444975853,
#    0.001066669705323875,
#    -0.06203601509332657,
#    -0.04510023072361946,
#    0.004087416455149651,
#    -0.003286752849817276,
#    -0.04952503368258476,
#    -0.07199247181415558,
#    0.0328700877726078,
#    0.03412719443440437,
#    -0.04707580432295799,
#    -0.04984891414642334,
#    -0.017115022987127304,
#    0.0894135907292366,
#    -0.04298828914761543,
#    -0.06454932689666748,
#    -0.036133117973804474,
#    0.001223515602760017,
#    0.0022011648397892714,
#    -0.0553860105574131,
#    0.03292061761021614,
#    -0.0398440808057785,
#    0.041251033544540405,
#    -0.013002261519432068,
#    0.07021893560886383,
#    0.0355764739215374,
#    -0.005204608663916588,
#    -0.0191907100379467,
#    -0.10254602879285812,
#    0.045571714639663696,
#    -0.001047045923769474,
#    0.06284799426794052,
#    0.031631868332624435,
#    -0.03272596746683121,
#    -0.09739939123392105,
#    -0.09767336398363113,
#    -0.03535590320825577,
#    -0.034597307443618774,
#    -0.05652971938252449,
#    -0.05587498098611832,
#    0.06941588222980499,
#    0.0048174746334552765,
#    -0.012630845420062542,
#    -0.07550953328609467,
#    0.022540193051099777,
#    0.018241604790091515,
#    0.026668479666113853,
#    0.0019742490258067846,
#    0.0447392463684082,
#    0.01457588654011488,
#    -0.006948225200176239,
#    0.01968834549188614,
#    0.011513957753777504,
#    0.04391780123114586,
#    -0.0335395522415638,
#    -0.03507014364004135,
#    0.061319589614868164,
#    -0.0028479136526584625,
#    -0.03557070717215538,
#    0.028153393417596817,
#    0.02631298638880253,
#    -0.05687941238284111,
#    -0.02519931085407734,
#    0.008815894834697247,
#    -0.06280972063541412,
#    0.015268540009856224,
#    -0.04402754083275795,
#    -0.06580005586147308,
#    -0.07724291831254959,
#    -0.04742749407887459,
#    0.002279166365042329,
#    0.02171149104833603,
#    -0.013681150041520596,
#    -0.04549742490053177,
#    -0.07271155714988708,
#    -0.004417307209223509,
#    0.07548990100622177,
#    0.0010730441426858306,
#    0.036170683801174164,
#    0.04138324409723282,
#    0.005054898094385862,
#    -0.08345198631286621,
#    -0.011352058500051498,
#    -0.11786744743585587,
#    0.06482864171266556,
#    -0.08761308342218399,
#    0.07871155440807343,
#    -0.02921115979552269,
#    0.025929667055606842,
#    -0.05402819812297821,
#    0.03349839523434639,
#    -0.0312613919377327,
#    -0.10820584744215012,
#    0.0500677227973938,
#    -0.11116330325603485,
#    0.0302526094019413,
#    -0.007427040953189135,
#    -0.06704258918762207,
#    -0.04411053657531738,
#    -0.08430305868387222,
#    0.009238951839506626,
#    0.019090520218014717,
#    -0.04093968868255615,
#    0.0011217218125239015,
#    -0.011850092560052872,
#    -0.008091392926871777,
#    -0.053429096937179565,
#    0.01452874019742012,
#    0.03921739012002945,
#    -0.0697583481669426,
#    0.015026940032839775,
#    -0.016963060945272446,
#    -0.0858745127916336,
#    -0.033955931663513184,
#    -1.668313680596619e-30,
#    -0.011539936065673828,
#    -0.030364012345671654,
#    -0.0276014506816864,
#    0.018605664372444153,
#    -0.03232535719871521,
#    0.05100944638252258,
#    -0.09967929869890213,
#    -0.04548021778464317,
#    -0.03884293511509895,
#    0.08902689814567566,
#    -0.01113614346832037,
#    -0.0387570858001709,
#    0.002637950936332345,
#    -0.01779085211455822,
#    0.016893962398171425,
#    -0.003454745514318347,
#    -0.05515927076339722,
#    0.07077714800834656,
#    0.06523355096578598,
#    -0.012622972950339317,
#    0.08821900188922882,
#    0.02330281399190426,
#    -0.010855589993298054,
#    -0.047352492809295654,
#    0.005384387914091349,
#    -0.057723212987184525,
#    0.061543188989162445,
#    -0.08358941227197647,
#    -0.00526713952422142,
#    0.07740434259176254,
#    -0.012729749083518982,
#    0.03836465999484062,
#    -0.021853221580386162,
#    -0.04155881330370903,
#    -0.009316781535744667,
#    -0.04437095299363136,
#    -0.016971027478575706,
#    0.015017236582934856,
#    0.040282536298036575,
#    -0.017878759652376175,
#    -0.004606266971677542,
#    0.038692545145750046,
#    -0.0502324104309082,
#    0.0547577366232872,
#    0.02783294767141342,
#    0.0886683538556099,
#    0.004391971044242382,
#    -0.06154245883226395,
#    -0.055043090134859085,
#    -0.04324749857187271,
#    0.026644090190529823,
#    -0.026123197749257088,
#    0.06581129133701324,
#    0.025118771940469742,
#    0.05512430891394615,
#    -0.011472023092210293,
#    -0.008573097176849842,
#    -0.011540315113961697,
#    -0.0320374071598053,
#    -0.0008061808184720576,
#    -0.02796388976275921,
#    0.09626979380846024,
#    0.08419905602931976,
#    0.009772446006536484,
#    0.02156853675842285,
#    0.01747797429561615,
#    -0.011735551990568638,
#    -0.06087139993906021,
#    0.07513286918401718,
#    -0.08635750412940979,
#    0.04264364391565323,
#    -0.035535119473934174,
#    0.024213610216975212,
#    -0.009337312541902065,
#    -0.12285469472408295,
#    0.03616001084446907,
#    -0.060984376817941666,
#    -0.0460776761174202,
#    0.008390802890062332,
#    0.006093089003115892,
#    -0.0361328162252903,
#    -0.009490144439041615,
#    -0.005577028729021549,
#    -0.020812438800930977,
#    0.04616251587867737,
#    0.0066139898262917995,
#    0.029164059087634087,
#    -0.08552321791648865,
#    0.027025757357478142,
#    0.066263347864151,
#    -0.08576853573322296,
#    0.012437883764505386,
#    0.022223088890314102,
#    -0.09065954387187958,
#    -0.09105082601308823,
#    -8.830101239709906e-33,
#    0.0007201603148132563,
#    0.011173511855304241,
#    0.03674359247088432,
#    0.059725258499383926,
#    -0.008468663319945335,
#    -0.08358149975538254,
#    0.03137907013297081,
#    0.09038317203521729,
#    0.0422811284661293,
#    0.014304885640740395,
#    0.038478750735521317,
#    -0.10288020223379135,
#    -0.004727233666926622,
#    -0.011480682529509068,
#    0.04776938632130623,
#    -0.04930870234966278,
#    0.09070821851491928,
#    0.06908480077981949,
#    -0.017501920461654663,
#    0.024825122207403183,
#    -0.026085127145051956,
#    0.1558428853750229,
#    -0.010965121909976006,
#    0.10931459069252014,
#    0.03532900661230087,
#    0.005962420720607042,
#    0.1058642715215683,
#    0.08082658797502518,
#    -0.12970967590808868,
#    -0.05106791481375694,
#    -0.04129548370838165,
#    -0.03718748316168785,
#    -0.08567718416452408,
#    0.07919489592313766,
#    -0.008289868012070656,
#    -0.02922722138464451,
#    0.004485681653022766,
#    0.023046955466270447,
#    -0.05236361548304558,
#    -0.045223113149404526,
#    0.011291052214801311,
#    -0.007456799503415823,
#    -0.006232261657714844,
#    0.07412683963775635,
#    0.046534374356269836,
#    -0.01984371989965439,
#    0.015533113852143288,
#    0.034248314797878265,
#    -0.07908228784799576,
#    -0.014670757576823235,
#    0.05075610801577568,
#    -0.004546296317130327,
#    -0.009430172853171825,
#    -0.08690528571605682,
#    0.046980585902929306,
#    0.06268711388111115,
#    0.047812845557928085,
#    0.021726801991462708,
#    0.09738548845052719,
#    -0.040537334978580475,
#    0.07517743110656738,
#    -0.013548305258154869,
#    -0.015444999560713768,
#    -0.03953676298260689,
#    0.10840503126382828,
#    -0.0003634145250543952,
#    0.08629857003688812,
#    0.058317046612501144,
#    0.09728849679231644,
#    -0.011892734095454216,
#    -0.01139879785478115,
#    -0.049576207995414734,
#    -0.0475630983710289,
#    -0.1898989975452423,
#    0.0016289858613163233,
#    0.05419010668992996,
#    -0.026976367458701134,
#    0.07930805534124374,
#    0.039862260222435,
#    -0.008812712505459785,
#    -0.0263462383300066,
#    -0.0015886833425611258,
#    -0.0354217030107975,
#    -0.040749624371528625,
#    0.03217001259326935,
#    -0.05993827059864998,
#    0.0038963283877819777,
#    0.012543993070721626,
#    0.012797116301953793,
#    0.05006896331906319,
#    -0.03591340407729149,
#    -0.0017974604852497578,
#    -0.07224846631288528,
#    -0.010023793205618858,
#    0.0033494140952825546,
#    -4.103044297103978e-33,
#    0.0416555218398571,
#    -0.05849133059382439,
#    0.08013204485177994,
#    -0.0033144319895654917,
#    0.11233282089233398,
#    -0.01960356906056404,
#    -0.03051692806184292,
#    -0.00820889137685299,
#    0.024358218535780907,
#    -0.07224918901920319,
#    0.07419898360967636,
#    0.01811927929520607,
#    -0.010449911467730999,
#    0.019974086433649063,
#    0.030934184789657593,
#    0.003921103198081255,
#    -0.02004198357462883,
#    0.023235507309436798,
#    -0.018362734466791153,
#    -0.0002140679571311921,
#    0.004702247679233551,
#    0.026073895394802094,
#    -0.006553030107170343,
#    -0.020851219072937965,
#    -0.02865351364016533,
#    0.016258208081126213,
#    -0.0589694082736969,
#    0.03693177178502083,
#    -0.08646578341722488,
#    0.01649099960923195,
#    0.019149575382471085,
#    -0.08259297907352448,
#    0.005432999227195978,
#    -0.036310553550720215,
#    -0.018816016614437103,
#    -0.030276518315076828,
#    -0.00977442879229784,
#    -0.03267670422792435,
#    0.026994474232196808,
#    -0.02441750094294548,
#    -0.061434462666511536,
#    -0.01435644831508398,
#    0.08576387166976929,
#    0.14256466925144196,
#    -0.0359734483063221,
#    -0.000299747014651075,
#    -0.0084078973159194,
#    -0.027119172737002373,
#    0.008481450378894806,
#    -0.008702738210558891,
#    -0.038534361869096756,
#    -0.015712212771177292,
#    -0.013345137238502502,
#    -0.027365321293473244,
#    0.02669449895620346,
#    -0.026597682386636734,
#    0.08452626317739487,
#    0.013942117802798748,
#    -0.11284619569778442,
#    0.026899026706814766,
#    0.06498368829488754,
#    0.06271306425333023,
#    -0.033055443316698074,
#    -0.028542011976242065],
#   [-0.024607351049780846,
#    0.07627987861633301,
#    0.04064882919192314,
#    -0.04991837590932846,
#    -0.006718565709888935,
#    -0.0463932640850544,
#    0.16574440896511078,
#    -0.019612211734056473,
#    0.033798933029174805,
#    -0.06323660910129547,
#    0.04889972135424614,
#    -0.02160867676138878,
#    0.08512397855520248,
#    0.02632434293627739,
#    0.0646079033613205,
#    -0.0421687588095665,
#    -0.015264216810464859,
#    0.03742462769150734,
#    -0.03932242840528488,
#    -0.03871637582778931,
#    -0.05975256860256195,
#    0.04073653370141983,
#    0.030979743227362633,
#    0.0009972803527489305,
#    -0.04173557460308075,
#    -0.03126154839992523,
#    0.07675553858280182,
#    -0.004373828414827585,
#    -0.02161267399787903,
#    0.011273618787527084,
#    -0.019702740013599396,
#    -0.03430740535259247,
#    -0.0557757243514061,
#    0.00803578831255436,
#    -0.0549502857029438,
#    0.0088721364736557,
#    -0.05791414901614189,
#    0.04147995635867119,
#    -0.0024213765282183886,
#    0.016192087903618813,
#    -0.06833109259605408,
#    -0.1270914077758789,
#    0.017888540402054787,
#    0.009792888537049294,
#    0.05720443278551102,
#    0.035621028393507004,
#    -0.0644557774066925,
#    -0.07993259280920029,
#    -0.09427313506603241,
#    -0.049134574830532074,
#    -0.05200079083442688,
#    -0.07127586752176285,
#    -0.03124528005719185,
#    0.08626546710729599,
#    -0.0009191107237711549,
#    -0.009649655781686306,
#    -0.09288866072893143,
#    0.008834760636091232,
#    0.029398281127214432,
#    0.001970035256817937,
#    -0.02734876237809658,
#    0.032789431512355804,
#    0.01343759149312973,
#    0.03051864728331566,
#    0.0067549291998147964,
#    0.028371667489409447,
#    0.03231768682599068,
#    -0.011257234029471874,
#    -0.0030881178099662066,
#    0.031143277883529663,
#    0.03863866254687309,
#    -0.04842102900147438,
#    0.028685899451375008,
#    0.05855945870280266,
#    -0.05053145810961723,
#    0.0020352848805487156,
#    0.05600086227059364,
#    -0.022434117272496223,
#    0.021612003445625305,
#    -0.02936618961393833,
#    -0.0059048025868833065,
#    -0.08395447582006454,
#    -0.043206311762332916,
#    0.0394279770553112,
#    0.0634630098938942,
#    -0.0039308457635343075,
#    -0.043653663247823715,
#    -0.004125190433114767,
#    0.006489277817308903,
#    0.054828912019729614,
#    0.04564106464385986,
#    0.017745554447174072,
#    -0.005277504678815603,
#    0.03668100759387016,
#    -0.14194193482398987,
#    0.0066713509149849415,
#    -0.08917694538831711,
#    -0.015187131240963936,
#    -0.09864971786737442,
#    0.07674572616815567,
#    0.02944277971982956,
#    -0.008313564583659172,
#    -0.015310085378587246,
#    0.011039122939109802,
#    -0.022092299535870552,
#    -0.05537201091647148,
#    0.05203621834516525,
#    -0.07609058171510696,
#    0.0380050465464592,
#    0.004507114179432392,
#    -0.05482010915875435,
#    -0.02072044461965561,
#    -0.0700128898024559,
#    0.014113375917077065,
#    0.01484138984233141,
#    -0.06651157140731812,
#    -0.024467479437589645,
#    0.04087439179420471,
#    0.008046720176935196,
#    -0.01172318123281002,
#    0.04676986485719681,
#    0.06443055719137192,
#    -0.06937796622514725,
#    0.0001537684292998165,
#    -0.03938188776373863,
#    -0.03328266739845276,
#    -0.015444358810782433,
#    -1.7253022109617718e-30,
#    0.0031252310145646334,
#    -0.06716009229421616,
#    -0.04692249745130539,
#    0.013470319099724293,
#    -0.06889225542545319,
#    0.08447746932506561,
#    -0.11066288501024246,
#    -0.022669512778520584,
#    -0.06629651039838791,
#    -0.019622478634119034,
#    -0.002426826162263751,
#    -0.0420733280479908,
#    -0.034634385257959366,
#    0.0026544914580881596,
#    0.035543713718652725,
#    -2.8493695936049335e-05,
#    0.01204574666917324,
#    0.016534050926566124,
#    0.07770485430955887,
#    0.04796448349952698,
#    0.045988425612449646,
#    -0.010249298997223377,
#    0.03577204421162605,
#    0.007825116626918316,
#    0.03423287346959114,
#    -0.06884845346212387,
#    0.03719985485076904,
#    -0.06457890570163727,
#    -0.03981466963887215,
#    0.09062466770410538,
#    0.004990293178707361,
#    -0.0038980471435934305,
#    -0.018567297607660294,
#    -0.06481300294399261,
#    0.002131125656887889,
#    -0.05515766516327858,
#    -0.016210347414016724,
#    -0.012150789611041546,
#    0.04423567280173302,
#    -0.026265641674399376,
#    -0.04362983629107475,
#    0.018216732889413834,
#    -0.07398288697004318,
#    0.0364183709025383,
#    0.03963375464081764,
#    0.059859540313482285,
#    0.03584672510623932,
#    -0.0001199152393382974,
#    0.015504428185522556,
#    -0.06272102147340775,
#    -0.04754788801074028,
#    -0.000560692569706589,
#    0.01328850258141756,
#    -0.004836744628846645,
#    0.05286363139748573,
#    0.0019316987600177526,
#    0.052683304995298386,
#    0.02615215815603733,
#    0.011432650499045849,
#    -0.02478405460715294,
#    -0.045550331473350525,
#    0.09152968972921371,
#    0.05311591550707817,
#    -0.09646961092948914,
#    0.029959924519062042,
#    0.00036665299558080733,
#    -0.032250091433525085,
#    -0.011554727330803871,
#    0.09021538496017456,
#    -0.11484293639659882,
#    0.009187058545649052,
#    -0.046191610395908356,
#    0.047953881323337555,
#    0.028328094631433487,
#    -0.11187506467103958,
#    0.01953030750155449,
#    0.006650760304182768,
#    -0.01872827112674713,
#    -0.0001950254081748426,
#    0.022233111783862114,
#    -0.024342570453882217,
#    0.023671241477131844,
#    -0.005601547658443451,
#    0.004162142984569073,
#    0.06438755989074707,
#    0.04051971808075905,
#    0.06435053795576096,
#    -0.07710637152194977,
#    0.011874411255121231,
#    0.13076423108577728,
#    -0.06003093719482422,
#    0.003520859405398369,
#    0.005468426737934351,
#    -0.009259181097149849,
#    -0.06809341907501221,
#    -8.166995325519454e-33,
#    -0.08739026635885239,
#    0.050062358379364014,
#    0.010753137059509754,
#    0.022631263360381126,
#    -0.033973969519138336,
#    -0.09994778782129288,
#    -0.00020987630705349147,
#    0.06295748800039291,
#    0.04020796716213226,
#    0.07152603566646576,
#    0.0030818521045148373,
#    -0.04972656071186066,
#    0.03596203774213791,
#    -0.002374280011281371,
#    -0.02034403569996357,
#    0.008030968718230724,
#    0.04068896546959877,
#    0.06764567643404007,
#    -0.0075956061482429504,
#    0.042827058583498,
#    -0.07645326107740402,
#    0.060645245015621185,
#    0.00589757552370429,
#    0.09595853835344315,
#    0.020254001021385193,
#    -0.06634221971035004,
#    0.1390029489994049,
#    0.05201919749379158,
#    -0.1047462522983551,
#    -0.05682488903403282,
#    0.020489761605858803,
#    -0.06074688956141472,
#    0.0008058528183028102,
#    0.08516336977481842,
#    -0.007427270524203777,
#    -0.05817713215947151,
#    0.07045171409845352,
#    -0.07214545458555222,
#    0.012011542916297913,
#    -0.044975556433200836,
#    0.049969397485256195,
#    -0.009030844084918499,
#    -0.008009749464690685,
#    0.012923851609230042,
#    0.0035567639861255884,
#    -0.03338877111673355,
#    -0.010794046334922314,
#    0.00597534840926528,
#    -0.02600990980863571,
#    -0.04860517010092735,
#    0.0678824856877327,
#    -0.03188176453113556,
#    -0.027533801272511482,
#    -0.07149378955364227,
#    0.08059996366500854,
#    0.03481817990541458,
#    -0.009450867772102356,
#    0.021467238664627075,
#    0.12333344668149948,
#    -0.10064700990915298,
#    0.019797734916210175,
#    0.0019734958186745644,
#    -0.024958066642284393,
#    -0.014892295002937317,
#    0.09961013495922089,
#    -0.0001158239392680116,
#    0.06700197607278824,
#    0.06897339969873428,
#    0.07315994799137115,
#    0.0026317795272916555,
#    -0.04438653960824013,
#    -0.030566012486815453,
#    -0.04537069424986839,
#    -0.1580459326505661,
#    -0.0026689262595027685,
#    0.05287005007266998,
#    -0.003585454076528549,
#    0.007907579652965069,
#    0.024177784100174904,
#    -0.05422908440232277,
#    0.016538385301828384,
#    0.06602480262517929,
#    -0.02838282845914364,
#    -0.10497835278511047,
#    0.04231499135494232,
#    -0.04860561713576317,
#    0.0014687074581161141,
#    0.07352866977453232,
#    -0.034768618643283844,
#    0.02001945674419403,
#    -0.041633348912000656,
#    0.05985082685947418,
#    -0.06970420479774475,
#    -0.043685249984264374,
#    0.017601247876882553,
#    -3.1363736708048893e-34,
#    0.05817955732345581,
#    -0.050555214285850525,
#    0.0904800146818161,
#    -0.020670289173722267,
#    0.09228517860174179,
#    -0.06594858318567276,
#    -0.0022614772897213697,
#    -0.020188072696328163,
#    0.03696133941411972,
#    -0.018565209582448006,
#    0.06078724190592766,
#    0.006943812593817711,
#    0.0007107200217433274,
#    0.010973592288792133,
#    0.035660769790410995,
#    -0.002081861486658454,
#    0.004479122348129749,
#    -0.01003887876868248,
#    -0.001505794352851808,
#    0.010916592553257942,
#    0.03781342878937721,
#    -0.05979179963469505,
#    0.01280251331627369,
#    0.06009765714406967,
#    -0.024863123893737793,
#    -0.026638664305210114,
#    -0.06749226897954941,
#    0.004076581448316574,
#    -0.09203975647687912,
#    -0.04971541836857796,
#    -0.02540695108473301,
#    -0.05100841447710991,
#    0.001540669589303434,
#    -0.041895925998687744,
#    0.007607216481119394,
#    -0.019938772544264793,
#    -0.04100525751709938,
#    -0.07529012858867645,
#    0.044585973024368286,
#    -0.014967956580221653,
#    -0.03445115312933922,
#    -0.10149312764406204,
#    0.08077733218669891,
#    0.13630062341690063,
#    -0.05353569984436035,
#    -0.037925515323877335,
#    0.01305930782109499,
#    -0.08563999831676483,
#    -0.01936398819088936,
#    -0.008557095192372799,
#    -0.06582778692245483,
#    -0.07174257189035416,
#    0.01785958744585514,
#    0.0005306904786266387,
#    0.062471091747283936,
#    -0.032265108078718185,
#    0.06210986524820328,
#    0.05589822307229042,
#    -0.11867760121822357,
#    -0.003495844779536128,
#    0.013712560757994652,
#    0.09488159418106079,
#    -0.06665243208408356,
#    -0.12438414990901947]],
#  'metadatas': [None, None],
#  'documents': ['부가가치세 예정신고에 대해 빠르게 알고 싶습니다.\n저는 대학원생이고 오는 25일이 부가가치세 예정신고일이라고 들었습니다. 일전에 있던 회사에서 세무사에게 모든 것을 대어맡으니 이제부터 막막하네요. 혹시 세무사를 찾아가지 않아도 세금계산서와 도장만 있으면 신고가 가능한 건가요? 그리고 사무실에서 쓰는 전기요금, 임대료, 사무용품 등 경비매출전표와 신용카드매출전표는 어떻게 해야 할까요? 그리고, 왜 예정신고와 확정신고가 있는 건가요?',
#   '용병 선수의 골키퍼 영입이 금지된 이유는 무엇인가요?\n축구에서 골키퍼는 매우 중요한 위치에 있습니다. 그렇다면, 외국인 선수 중에서도 골키퍼는 왜 영입하지 않을까요?'],
#  'data': None,
#  'uris': None}

# %%
txt = '최초의 애니메이션은 ?'
print(txt)

results = emb_collection.query(
    query_texts = txt, 
    n_results = 5,
    # include=['distances'],
    # where={"source": {"$eq": "closed_qa"}},
    # where_document={"$contains":"safe"}
)

results
# Out:
# 최초의 애니메이션은 ?
# {'ids': [['2309', '3341', '2736', '3406', '1613']],
#  'distances': [[0.7564581632614136,
#    0.7682268619537354,
#    0.7768236398696899,
#    0.7787466645240784,
#    0.7847808003425598]],
#  'embeddings': None,
#  'metadatas': [[None, None, None, None, None]],
#  'documents': [['울산에 까마귀가 많은 이유는 무엇일까요?',
#    '왜 세계시간의 기준이 영국의 GMT인가요? 그 이유는 무엇일까요?',
#    '설탕이 인체에 끼치는 유해성은 무엇인가요?',
#    '다윈개구리는 수컷이 알을 입속에 넣고 기른다는 것이 사실인가요??',
#    '사진에서 이러한 물결무늬는 왜 생기는 건가요? 해상도가 안 맞나요?']],
#  'uris': None,
#  'data': None}

# %%
import chromadb
import os 
import torch
import openai
import getpass
import pandas as pd 
import numpy as np 
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer, AutoModel
from llama_index.embeddings import HuggingFaceEmbedding

# %%
data_path = os.path.join('/workspace/data/')

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")
openai.api_key = os.environ["OPENAI_API_KEY"]
# Out:
# OpenAI API Key: ········

# %%
card = pd.read_csv(os.path.join(data_path, 'financial', 'SHINHAN BANK_Financial_Product_Scraping_Result_20240104_CARD_vec.csv'))
deposit = pd.read_csv(os.path.join(data_path, 'financial', 'SHINHAN BANK_Financial_Product_Scraping_Result_20240104_DEPOSIT_vec.csv'))
loan = pd.read_csv(os.path.join(data_path, 'financial', 'SHINHAN BANK_Financial_Product_Scraping_Result_20240104_LOAN_vec.csv'))

# %%
print(f'card table columns: {card.columns}', end='\n\n')
print(f'deposit table columns: {deposit.columns}', end='\n\n')
print(f'loan table columns: {loan.columns}', end='\n\n')
# Out:
# card table columns: Index(['카드_고유키', '카드설명'], dtype='object')
#
# deposit table columns: Index(['보증_고유키', '상품설명'], dtype='object')
#
# loan table columns: Index(['대출_고유키', '상품특징', '대출신청자격', '상품설명'], dtype='object')

# %%
card.isna().sum()
# Out:
# 카드_고유키      0
# 카드설명      110
# dtype: int64

# %%
model_name = 'kakaobank/kf-deberta-base'

# %%
# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
hugging_face_ef = embedding_functions.HuggingFaceEmbeddingFunction(
	api_key='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',
	model_name=model_name
)

# %% [markdown]
# ##### HuggingFaceEmbedding Func <-> AutoTokenizer Embedding 값 일치 여부 확인

# %%
tmp_emb = hugging_face_ef(['kakaobank/kf-deberta-base'])
np.mean(np.squeeze(tmp_emb), axis=0)[:3]
# Out:
# array([0.71556843, 0.85814735, 0.33519265])

# %%
def get_emb(tokenizer, model, doc):
    encoded_input = tokenizer(doc, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        model_output = model(**encoded_input)
    
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    sentence_embeddings= list(map(float, sentence_embeddings[0]))
    return sentence_embeddings

# %%
def get_metadata(columns, data, idx):
    meta_dict = dict()
    for col in columns:
        try:
            assert meta_dict[col]
        except:
            meta_dict[col] = data[col][idx]
    return meta_dict

# %%
# Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# %%
get_emb(tokenizer, model, '새로운 세상')[:3]
# Out:
# [-0.5291522741317749, 0.8925473690032959, -1.7507115602493286]

# %%
hugging_face_ef

# %% [markdown]
# ### ChromaDB

# %%
from chromadb.utils import embedding_functions

# %%
chroma_client = chromadb.HttpClient(host='172.19.240.1', port=8000)

# %% [raw]
# chroma_card = chroma_client.create_collection(name='card', embedding_function=hugging_face_ef)
# chroma_loan = chroma_client.create_collection(name='loan', embedding_function=hugging_face_ef)
# chroma_deposit = chroma_client.create_collection(name='deposit', embedding_function=hugging_face_ef)

# %% [raw]
# chroma_features = chroma_client.create_collection(name='features', embedding_function=hugging_face_ef)

# %%
chroma_card = chroma_client.get_collection(name='card')
chroma_loan = chroma_client.get_collection(name='loan')
chroma_deposit = chroma_client.get_collection(name='deposit')

# %%
db.list_collections()
# Out:
# []

# %% [raw]
# chroma_client.delete_collection('features')

# %%
loan.columns

# %%
meta_col = ['대출_고유키']
vector_col = ['상품특징']

# %%
start_idx = 0

# %%
for col in vector_col: 
    # tb_docs = deposit.dropna(subset=col, axis=0)
    loan.reset_index(inplace=True, drop=True)
    documents = loan[col].values.tolist()
    
    ids = []; docs = []; embeddings = []; metadatas = []
    
    for idx in range(len(loan)):
        try:
            emb = get_emb(tokenizer, model, documents[idx])
        except:
            continue 
        start_idx += 1
        ids.append(str(start_idx))
        docs.append(documents[idx])
        
        # print(np.shape(emb))
        embeddings.append(emb)
        meta_dict = get_metadata(meta_col, loan, idx)
        metadatas.append(meta_dict)

    chroma_features.add(
    ids=ids,
    documents=docs, 
    embeddings=embeddings,
    metadatas=metadatas
    )
    print(f'column: {col}완료, chroma_feat 데이터 개수: {chroma_features.count()}')

# %%
txt = ' 대출'
emb = get_emb(tokenizer, model, txt)

results = chroma_desc.query(
    query_embeddings = emb,
    n_results = 3
)
results

# %% [markdown]
# ### Persistent Directory

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext 
from llama_index.vector_stores import ChromaVectorStore 
from llama_index.storage.storage_context import StorageContext 
from pathlib import Path
from llama_index import download_loader

# %%
db = chromadb.PersistentClient(path='/workspace/db/chroma')

# %%
embed_model = HuggingFaceEmbedding(model_name=model_name)

# %%
db.list_collections()
# Out:
# [Collection(name=features)]

# %%
chroma_features = db.create_collection(name='features', embedding_function=hugging_face_ef)

# %%
reader = SimpleDirectoryReader(input_files=['/workspace/data/financial/SHINHAN BANK_Financial_Product_Scraping_Result_20240104_CARD_vec.csv'])
reader.load_data()[0].text
# Out:
# '카드_0, nan\n카드_1, 바다위새로운세상휴먼라이프크루즈여행을위한맞춤혜택\n카드_2, 7개업종중선택한1개업종가맹점에서카드사용시7%청구할인\n카드_3, 법인/개인사업자에최적화된혜택을드리는카드\n카드_4, 국고보조금집행시사용되는카드\n카드_5, 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자에게발급해드리는카드\n카드_6, 국가바우처통합카드\n카드_7, 특별한1%의당신을위해남다른품격과가치의시작\n카드_8, 특별한1%의당신을위해남다른품격과가치의시작\n카드_9, 성공비즈니스를위한든든한파트너\n카드_10, ILoveDokdo\n카드_11, 대한민국우리의땅독도를지킵시다\n카드_12, 신용카드고유기능을이용하는법인신용카드로포인트약정기업회원연안여객포인트적립,바다마트청구할인\n카드_13, 행복한생활,쇼핑의즐거움\n카드_14, 생활도Green,카드도Green일상속에서손쉽게녹색생활을실천하고그린카드로우리가족생활비절약은물론다양한혜택까지~\n카드_15, 투명하고효율적인정부예산집행정부관서모든예산과목의운영경비를정부구매카드로지출하세요.\n카드_16, 회원의카드이용금액에따라제휴업체인대한항공의스카이패스마일리지를적립해주는상품\n카드_17, 수협은행제휴학교전용체크카드\n카드_18, 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자및대상자에게발급해드리는체크카드\n카드_19, 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자및대상자에게발급해드리는체크카드\n카드_20, 국가바우처통합카드\n카드_21, 생활도Green,카드도Green일상속에서손쉽게녹색생활을실천하고그린카드로우리가족생활비절약은물론다양한혜택까지~\n카드_22, 제주도청에서민간(개인및단체)에지원되는보조금예산에대한집행을수협은행에서발행된보조금전용카드를통하여집행하도록발행된카드\n카드_23, 코웨이 렌탈요금 청구할인!\n카드_24, SK매직 렌탈요금 청구할인!\n카드_25, LG전자 구독요금 청구할인과 장기할부 서비스!\n카드_26, 바디프랜드 렌탈요금 청구할인과 장기할부 서비스!\n카드_27, 넥센타이어 렌탈요금 청구할인!\n카드_28, 쿠쿠 렌탈요금 청구할인과 장기할부 서비스!\n카드_29, NU 갤러리아 우리카드\n카드_30, 코오롱몰 상품 구매시 5% 청구할인 혜택 + 12/24/36개월 장기할부 청구할인 혜택까지!\n카드_31, 나를 위한 UNIQ한 선택\n카드_32, 오케이몰 상품을 24/36개월 장기할부로 구매하고, 월 최대 2만원 청구할인 혜택까지!\n카드_33, 국가바우처, 임신/출산, 보육/교육, 쇼핑, 해외, 언택트라이프 혜택까지 모두 담다!!\n카드_34, 국가바우처, 임신/출산, 보육/교육, 쇼핑, 해외, 언택트라이프 혜택까지 모두 담다!!\n카드_35, AK 우리카드에 AK 쇼핑의 혜택을 전부 담다\n카드_36, 카드의정석 넥센타이어 렌탈 우리카드\n카드_37, 모든 백화점, 대형마트, 주유소에서&lt /5% 청구할인\n카드_38, 전통시장에서 장볼때 최대 5%까지,&lt/대중교통비 5% 할인되는 알뜰한 카드!\n카드_39, 세라젬 제품 구매하고&ltBR기분좋은 청구할인 혜택까지!\n카드_40, 프뢰벨 제품 장기할부 구매 시 &lt 월 최대 2만원 청구할인 혜택!\n카드_41, 더배스트 렌탈 및 할부구매하고&lt 최대 2만원 할인받자!\n카드_42, 당신의 똑똑한 렌탈 라이프\n카드_43, BS 렌탈요금 할인서비스에 다양한 생활 혜택까지 누리자!\n카드_44, 코웨이 렌탈요금 자동이체하고&lt최대 2만원 할인받자!\n카드_45, 청호나이스 렌탈요금 자동이체하고 최대 2만원 할인받자!\n카드_46, 슬림할부로 청호나이스제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!\n카드_47, 슬림할부로 바디프랜드 제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!\n카드_48, 슬림할부로 쿠쿠제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!\n카드_49, 현대렌탈케어 렌탈요금 할인에, 다양한 생활 혜택까지 누리자!\n카드_50, 슬림할부로 코웨이제품 부담없이 구매하고 다양한 생활할인 혜택까지 누리자!\n카드_51, 대림케어 렌탈요금 할인에 다양한 생활 혜택까지!\n카드_52, 실속만점 생활할인은 기본!&ltBR렌탈요금/상조회비까지 할인받자 !\n카드_53, 실속있게 생활할인은 기본&lt /&ltem바디프랜드 렌탈요금 할인까지!&lt/em\n카드_54, 실속만점 생활할인은 기본!&lt이제 렌탈요금 까지 할인 받자!\n카드_55, GS25할인 5%, T머니 10% 할인 서비스\n카드_56, 2자녀 이상을 둔 가정에게 드리는&lt최대 특혜를 누리세요~!\n카드_57, 유가보조금 받고!&lt GS칼텍스 주유 할인까지!\n카드_58, 유가보조금 + 정유3사 주유할인을&lt 카드의정석 화물복지카드 한장으로!!\n카드_59, 전월실적 조건 없이 S-OIL 화물차우대주유소에서 주유 시 리터당 최대 50원 현장할인 제공\n카드_60, 전월실적 조건 없이 SK 내트럭플러스에서 주유 시 리터당 최대 50원 할인\n카드_61, S-OIL 주유소 리터당 120~400원 할인 서비스에 다양한 생활 &lt/ 혜택까지 누리자!\n카드_62, LPG 화물차 유가보조금 지원, E1 충전소 결제금액 1천원당 오렌지포인트 최대 30P 적립, 다양한 생활서비스 제공\n카드_63, SK주유소 리터당 120~400원 할인에&lt / 다양한 생활 혜택까지 누리자!\n카드_64, Auto 금융 할인 및 자동차 특화서비스에 다양한 생활 할인 혜택까지\n카드_65, 자동차 연비를 높이는 새로운 답을 제시하다!\n카드_66, 에코라서 가능한 혜택, 에코로 쌓는 더 많은 포인트\n카드_67, 건설기계 사업자의 성공 인프라!!\n카드_68, 할인혜택으로 레저의 즐거움이&lt/더욱 커진다!\n카드_69, LG U+ 통신요금 할인!\n카드_70, 너겟 통신요금 할인!\n카드_71, SKT 통신요금 할인!\n카드_72, KT 통신요금 할인!\n카드_73, KT 통신요금 할인!\n카드_74, LG U+ 통신요금 할인!\n카드_75, U+알뜰폰 통신요금 할인 혜택!\n카드_76, KT 알뜰폰 통신요금 할인!\n카드_77, 통신요금 할인에 다양한 할인 혜택까지!\n카드_78, 유가보조금 + 정유3사 주유할인, &lt우리 썸화물복지카드 단 한장으로!\n카드_79, 국방 가족을 위한 특별한 혜택을 담은 카드!&lt /군복지시설, 생활밀착형 할인 등 다양한 할인을 누리세요!\n카드_80, 군인연금수급자임을 증명하는 신분증 기능에 전국 군복지시설 및 5대 대표업종 청구할인, 버스요금 지원서비스\n카드_81, 국민연금수급자임을 증명하는 신분증 기능에 버스요금 매달 최대 5천원 지원과 다양한 카드 혜택 제공\n카드_82, 환경부 에코 프로젝트~ 그린을 꺼내세요!!\n카드_83, 환경부 에코 프로젝트~ 그린을 꺼내세요!!\n카드_84, 전국 어디서나 대중교통 10% 할인\n카드_85, 패밀리니까! 더 받는다! 생활에 필요한 다양한 실속 할인혜택\n카드_86, 패밀리니까! 더 받는다! 생활에 필요한 다양한 실속 할인혜택\n카드_87, 국기원 단증에 카드를 결합한 태권도인 특화 상품\n카드_88, 세례명카드 만들고 자동기부도 하고 다양한 혜택도 누리면서 적립된 포인트는 교구에 기부됩니다.\n카드_89, 적립된 상환용 적립 포인트를 자녀의 학자금 대출 원리금 상환에 활용하며, 기타 다양한 혜택을 누리세요~\n카드_90, 우리은행 주거래고객님을 위한 특별한 혜택! &lt /국내 모든 가맹점에서 0.5~1.5% 적립,&lt/6개월마다 15,000점 보너스 적립!\n카드_91, 우리은행 주거래고객님을 위한 특별한 혜택! &lt /국내 모든 가맹점에서 0.5~1.5% 적립,&lt/6개월마다 15,000점 보너스 적립!\n카드_92, 카드 한 장으로 신용카드 혜택과 &lt/한화그룹 계열사 서비스를 한번에 해결하자!\n카드_93, 카드 한 장으로 신용카드 혜택과 &lt/한화그룹 계열사 서비스를 한번에 해결하자!\n카드_94, 회사에 반했다! kt 그룹이 좋아졌다!\n카드_95, 모든 백화점, 대형마트, 병원, 서점에서 우리V카드만 있으면 365일 할인!\n카드_96, woori 할인서비스, 패밀리레스토랑 할인\n카드_97, 항공 마일리지 적립서비스, 주유 ...

# %%
PandasCSVReader = download_loader("SimpleCSVReader")

loader = SimpleCSVReader(encoding='utf-8')
documents = loader.load_data(file=Path('/workspace/data/financial/SHINHAN BANK_Financial_Product_Scraping_Result_20240104_CARD_vec.csv'))

# %%
PandasCSVReader = download_loader("PandasCSVReader")

loader = PandasCSVReader()
documents = loader.load_data(file=Path('/workspace/data/financial/SHINHAN BANK_Financial_Product_Scraping_Result_20240104_CARD_vec.csv'))

# %%
documents
# Out:
# [Document(id_='e117e2fe-466a-4817-9f7c-1e6e98929190', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='dbdc7054fdaf98e91be0f7bdd125389080e0d815a1cb1af76d3a89a928b4f6c6', text='카드_0, nan\n카드_1, 바다위새로운세상휴먼라이프크루즈여행을위한맞춤혜택\n카드_2, 7개업종중선택한1개업종가맹점에서카드사용시7%청구할인\n카드_3, 법인/개인사업자에최적화된혜택을드리는카드\n카드_4, 국고보조금집행시사용되는카드\n카드_5, 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자에게발급해드리는카드\n카드_6, 국가바우처통합카드\n카드_7, 특별한1%의당신을위해남다른품격과가치의시작\n카드_8, 특별한1%의당신을위해남다른품격과가치의시작\n카드_9, 성공비즈니스를위한든든한파트너\n카드_10, ILoveDokdo\n카드_11, 대한민국우리의땅독도를지킵시다\n카드_12, 신용카드고유기능을이용하는법인신용카드로포인트약정기업회원연안여객포인트적립,바다마트청구할인\n카드_13, 행복한생활,쇼핑의즐거움\n카드_14, 생활도Green,카드도Green일상속에서손쉽게녹색생활을실천하고그린카드로우리가족생활비절약은물론다양한혜택까지~\n카드_15, 투명하고효율적인정부예산집행정부관서모든예산과목의운영경비를정부구매카드로지출하세요.\n카드_16, 회원의카드이용금액에따라제휴업체인대한항공의스카이패스마일리지를적립해주는상품\n카드_17, 수협은행제휴학교전용체크카드\n카드_18, 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자및대상자에게발급해드리는체크카드\n카드_19, 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자및대상자에게발급해드리는체크카드\n카드_20, 국가바우처통합카드\n카드_21, 생활도Green,카드도Green일상속에서손쉽게녹색생활을실천하고그린카드로우리가족생활비절약은물론다양한혜택까지~\n카드_22, 제주도청에서민간(개인및단체)에지원되는보조금예산에대한집행을수협은행에서발행된보조금전용카드를통하여집행하도록발행된카드\n카드_23, 코웨이 렌탈요금 청구할인!\n카드_24, SK매직 렌탈요금 청구할인!\n카드_25, LG전자 구독요금 청구할인과 장기할부 서비스!\n카드_26, 바디프랜드 렌탈요금 청구할인과 장기할부 서비스!\n카드_27, 넥센타이어 렌탈요금 청구할인!\n카드_28, 쿠쿠 렌탈요금 청구할인과 장기할부 서비스!\n카드_29, NU 갤러리아 우리카드\n카드_30, 코오롱몰 상품 구매시 5% 청구할인 혜택 + 12/24/36개월 장기할부 청구할인 혜택까지!\n카드_31, 나를 위한 UNIQ한 선택\n카드_32, 오케이몰 상품을 24/36개월 장기할부로 구매하고, 월 최대 2만원 청구할인 혜택까지!\n카드_33, 국가바우처, 임신/출산, 보육/교육, 쇼핑, 해외, 언택트라이프 혜택까지 모두 담다!!\n카드_34, 국가바우처, 임신/출산, 보육/교육, 쇼핑, 해외, 언택트라이프 혜택까지 모두 담다!!\n카드_35, AK 우리카드에 AK 쇼핑의 혜택을 전부 담다\n카드_36, 카드의정석 넥센타이어 렌탈 우리카드\n카드_37, 모든 백화점, 대형마트, 주유소에서&lt /5% 청구할인\n카드_38, 전통시장에서 장볼때 최대 5%까지,&lt/대중교통비 5% 할인되는 알뜰한 카드!\n카드_39, 세라젬 제품 구매하고&ltBR기분좋은 청구할인 혜택까지!\n카드_40, 프뢰벨 제품 장기할부 구매 시 &lt 월 최대 2만원 청구할인 혜택!\n카드_41, 더배스트 렌탈 및 할부구매하고&lt 최대 2만원 할인받자!\n카드_42, 당신의 똑똑한 렌탈 라이프\n카드_43, BS 렌탈요금 할인서비스에 다양한 생활 혜택까지 누리자!\n카드_44, 코웨이 렌탈요금 자동이체하고&lt최대 2만원 할인받자!\n카드_45, 청호나이스 렌탈요금 자동이체하고 최대 2만원 할인받자!\n카드_46, 슬림할부로 청호나이스제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!\n카드_47, 슬림할부로 바디프랜드 제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!\n카드_48, 슬림할부로 쿠쿠제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!\n카드_49, 현대렌탈케어 렌탈요금 할인에, 다양한 생활 혜택까지 누리자!\n카드_50, 슬림할부로 코웨이제품 부담없이 구매하고 다양한 생활할인 혜택까지 누리자!\n카드_51, 대림케어 렌탈요금 할인에 다양한 생활 혜택까지!\n카드_52, 실속만점 생활할인은 기본!&ltBR렌탈요금/상조회비까지 할인받자 !\n카드_53, 실속있게 생활할인은 기본&lt /&ltem바디프랜드 렌탈요금 할인까지!&lt/em\n카드_54, 실속만점 생활할인은 기본!&lt이제 렌탈요금 까지 할인 받자!\n카드_55, GS25할인 5%, T머니 10% 할인 서비스\n카드_56, 2자녀 이상을 둔 가정에게 드리는&lt최대 특혜를 누리세요~!\n카드_57, 유가보조금 받고!&lt GS칼텍스 주유 할인까지!\n카드_58, 유가보조금 + 정유3사 주유할인을&lt 카드의정석 화물복지카드 한장으로!!\n카드_59, 전월실적 조건 없이 S-OIL 화물차우대주유소에서 주유 시 리터당 최대 50원 현장할인 제공\n카드_60, 전월실적 조건 없이 SK 내트럭플러스에서 주유 시 리터당 최대 50원 할인\n카드_61, S-OIL 주유소 리터당 120~400원 할인 서비스에 다양한 생활 &lt/ 혜택까지 누리자!\n카드_62, LPG 화물차 유가보조금 지원, E1 충전소 결제금액 1천원당 오렌지포인트 최대 30P 적립, 다양한 생활서비스 제공\n카드_63, SK주유소 리터당 120~400원 할인에&lt / 다양한 생활 혜택까지 누리자!\n카드_64, Auto 금융 할인 및 자동차 특화서비스에 다양한 생활 할인 혜택까지\n카드_65, 자동차 연비를 높이는 새로운 답을 제시하다!\n카드_66, 에코라서 가능한 혜택, 에코로 쌓는 더 많은 포인트\n카드_67, 건설기계 사업자의 성공 인프라!!\n카드_68, 할인혜택으로 레저의 즐거움이&lt/더욱 커진다!\n카드_69, LG U+ 통신요금 할인!\n카드_70, 너겟 통신요금 할인!\n카드_71, SKT 통신요금 할인!\n카드_72, KT 통신요금 할인!\n카드_73, KT 통신요금 할인!\n카드_74, LG U+ 통신요금 할인!\n카드_75, U+알뜰폰 통신요금 할인 혜택!\n카드_76, KT 알뜰폰 통신요금 할인!\n카드_77, 통신요금 할인에 다양한 할인 혜택까지!\n카드_78, 유가보조금 + 정유3사 주유할인, &lt우리 썸화물복지카드 단 한장으로!\n카드_79, 국방 가족을 위한 특별한 혜택을 담은 카드!&lt /군복지시설, 생활밀착형 할인 등 다양한 할인을 누리세요!\n카드_80, 군인연금수급자임을 증명하는 신분증 기능에 전국 군복지시설 및 5대 대표업종 청구할인, 버스요금 지원서비스\n카드_81, 국민연금수급자임을 증명하는 신분증 기능에 버스요금 매달 최대 5천원 지원과 다양한 카드 혜택 제공\n카드_82, 환경부 에코 프로젝트~ 그린을 꺼내세요!!\n카드_83, 환경부 에코 프로젝트~ 그린을 꺼내세요!!\n카드_84, 전국 어디서나 대중교통 10% 할인\n카드_85, 패밀리니까! 더 받는다! 생활에 필요한 다양한 실속 할인혜택\n카드_86, 패밀리니까! 더 받는다! 생활에 필요한 다양한 실속 할인혜택\n카드_87, 국기원 단증에 카드를 결합한 태권도인 특화 상품\n카드_88, 세례명카드 만들고 자동기부도 하고 다양한 혜택도 누리면서 적립된 포인트는 교구에 기부됩니다.\n카드_89, 적립된 상환용 적립 포인트를 자녀의 학자금 대출 원리금 상환에 활용하며, 기타 다양한 혜택을 누리세요~\n카드_90, 우리은행 주거래고객님을 위한 특별한 혜택! &lt /국내 모든 가맹점에서 0.5~1.5% 적립,&lt/6개월마다 15,000점 보너스 적립!\n카드_91, 우리은행 주거래고객님을 위한 특별한 혜택! &lt /국내 모든 가맹점에서 0.5~1.5% 적립,&lt/6개월마다 15,000점 보너스 적립!\n카드 ...

# %%
documents[0].metadata
# Out:
# {}

# %% [raw]
# all_docs = []
# for docs in reader.iter_data():
#     print(docs)
#     for doc in docs:
#         # do something with the doc
#         doc.text = doc.text.upper()
#         all_docs.append(doc)

# %%
data = pd.read_csv(os.path.join(data_path, 'financial', 'SHINHAN BANK_Financial_Product_Scraping_Result_20240104_CARD_vec.csv'))
data.dropna(subset=['카드설명'], inplace=True)
documents = data.카드설명.values.tolist()

# %%
tmp = data[['카드설명']]
tmp.to_csv(os.path.join(data_path, 'tmp.csv'), index=False)

# %%
data

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
documents = loader.load_data(file=Path('/workspace/data/tmp.csv'))

# %%
loader = CSVLoader(file_path='/workspace/data/tmp.csv')
documents = loader.load()

# %%
documents
# Out:
# [Document(page_content='카드설명: 바다위새로운세상휴먼라이프크루즈여행을위한맞춤혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 0}),
#  Document(page_content='카드설명: 7개업종중선택한1개업종가맹점에서카드사용시7%청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 1}),
#  Document(page_content='카드설명: 법인/개인사업자에최적화된혜택을드리는카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 2}),
#  Document(page_content='카드설명: 국고보조금집행시사용되는카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 3}),
#  Document(page_content='카드설명: 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자에게발급해드리는카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 4}),
#  Document(page_content='카드설명: 국가바우처통합카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 5}),
#  Document(page_content='카드설명: 특별한1%의당신을위해남다른품격과가치의시작', metadata={'source': '/workspace/data/tmp.csv', 'row': 6}),
#  Document(page_content='카드설명: 특별한1%의당신을위해남다른품격과가치의시작', metadata={'source': '/workspace/data/tmp.csv', 'row': 7}),
#  Document(page_content='카드설명: 성공비즈니스를위한든든한파트너', metadata={'source': '/workspace/data/tmp.csv', 'row': 8}),
#  Document(page_content='카드설명: ILoveDokdo', metadata={'source': '/workspace/data/tmp.csv', 'row': 9}),
#  Document(page_content='카드설명: 대한민국우리의땅독도를지킵시다', metadata={'source': '/workspace/data/tmp.csv', 'row': 10}),
#  Document(page_content='카드설명: 신용카드고유기능을이용하는법인신용카드로포인트약정기업회원연안여객포인트적립,바다마트청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 11}),
#  Document(page_content='카드설명: 행복한생활,쇼핑의즐거움', metadata={'source': '/workspace/data/tmp.csv', 'row': 12}),
#  Document(page_content='카드설명: 생활도Green,카드도Green일상속에서손쉽게녹색생활을실천하고그린카드로우리가족생활비절약은물론다양한혜택까지~', metadata={'source': '/workspace/data/tmp.csv', 'row': 13}),
#  Document(page_content='카드설명: 투명하고효율적인정부예산집행정부관서모든예산과목의운영경비를정부구매카드로지출하세요.', metadata={'source': '/workspace/data/tmp.csv', 'row': 14}),
#  Document(page_content='카드설명: 회원의카드이용금액에따라제휴업체인대한항공의스카이패스마일리지를적립해주는상품', metadata={'source': '/workspace/data/tmp.csv', 'row': 15}),
#  Document(page_content='카드설명: 수협은행제휴학교전용체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 16}),
#  Document(page_content='카드설명: 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자및대상자에게발급해드리는체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 17}),
#  Document(page_content='카드설명: 국고보조금집행시사용되는카드로써국고보조금을교부받는보조사업자및대상자에게발급해드리는체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 18}),
#  Document(page_content='카드설명: 국가바우처통합카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 19}),
#  Document(page_content='카드설명: 생활도Green,카드도Green일상속에서손쉽게녹색생활을실천하고그린카드로우리가족생활비절약은물론다양한혜택까지~', metadata={'source': '/workspace/data/tmp.csv', 'row': 20}),
#  Document(page_content='카드설명: 제주도청에서민간(개인및단체)에지원되는보조금예산에대한집행을수협은행에서발행된보조금전용카드를통하여집행하도록발행된카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 21}),
#  Document(page_content='카드설명: 코웨이 렌탈요금 청구할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 22}),
#  Document(page_content='카드설명: SK매직 렌탈요금 청구할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 23}),
#  Document(page_content='카드설명: LG전자 구독요금 청구할인과 장기할부 서비스!', metadata={'source': '/workspace/data/tmp.csv', 'row': 24}),
#  Document(page_content='카드설명: 바디프랜드 렌탈요금 청구할인과 장기할부 서비스!', metadata={'source': '/workspace/data/tmp.csv', 'row': 25}),
#  Document(page_content='카드설명: 넥센타이어 렌탈요금 청구할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 26}),
#  Document(page_content='카드설명: 쿠쿠 렌탈요금 청구할인과 장기할부 서비스!', metadata={'source': '/workspace/data/tmp.csv', 'row': 27}),
#  Document(page_content='카드설명: NU 갤러리아 우리카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 28}),
#  Document(page_content='카드설명: 코오롱몰 상품 구매시 5% 청구할인 혜택 + 12/24/36개월 장기할부 청구할인 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 29}),
#  Document(page_content='카드설명: 나를 위한 UNIQ한 선택', metadata={'source': '/workspace/data/tmp.csv', 'row': 30}),
#  Document(page_content='카드설명: 오케이몰 상품을 24/36개월 장기할부로 구매하고, 월 최대 2만원 청구할인 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 31}),
#  Document(page_content='카드설명: 국가바우처, 임신/출산, 보육/교육, 쇼핑, 해외, 언택트라이프 혜택까지 모두 담다!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 32}),
#  Document(page_content='카드설명: 국가바우처, 임신/출산, 보육/교육, 쇼핑, 해외, 언택트라이프 혜택까지 모두 담다!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 33}),
#  Document(page_content='카드설명: AK 우리카드에 AK 쇼핑의 혜택을 전부 담다', metadata={'source': '/workspace/data/tmp.csv', 'row': 34}),
#  Document(page_content='카드설명: 카드의정석 넥센타이어 렌탈 우리카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 35}),
#  Document(page_content='카드설명: 모든 백화점, 대형마트, 주유소에서&lt /5% 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 36}),
#  Document(page_content='카드설명: 전통시장에서 장볼때 최대 5%까지,&lt/대중교통비 5% 할인되는 알뜰한 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 37}),
#  Document(page_content='카드설명: 세라젬 제품 구매하고&ltBR기분좋은 청구할인 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 38}),
#  Document(page_content='카드설명: 프뢰벨 제품 장기할부 구매 시 &lt 월 최대 2만원 청구할인 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 39}),
#  Document(page_content='카드설명: 더배스트 렌탈 및 할부구매하고&lt 최대 2만원 할인받자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 40}),
#  Document(page_content='카드설명: 당신의 똑똑한 렌탈 라이프', metadata={'source': '/workspace/data/tmp.csv', 'row': 41}),
#  Document(page_content='카드설명: BS 렌탈요금 할인서비스에 다양한 생활 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 42}),
#  Document(page_content='카드설명: 코웨이 렌탈요금 자동이체하고&lt최대 2만원 할인받자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 43}),
#  Document(page_content='카드설명: 청호나이스 렌탈요금 자동이체하고 최대 2만원 할인받자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 44}),
#  Document(page_content='카드설명: 슬림할부로 청호나이스제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 45}),
#  Document(page_content='카드설명: 슬림할부로 바디프랜드 제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 46}),
#  Document(page_content='카드설명: 슬림할부로 쿠쿠제품 부담없이 구매하고, 다양한 생활 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 47}),
#  Document(page_content='카드설명: 현대렌탈케어 렌탈요금 할인에, 다양한 생활 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 48}),
#  Document(page_content='카드설명: 슬림할부로 코웨이제품 부담없이 구매하고 다양한 생활할인 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 49}),
#  Document(page_content='카드설명: 대림케어 렌탈요금 할인에 다양한 생활 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 50}),
#  Document(page_content='카드설명: 실속만점 생활할인은 기본!&ltBR렌탈요금/상조회비까지 할인받자 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 51}),
#  Document(page_content='카드설명: 실속있게 생활할인은 기본&lt /&ltem바디프랜드 렌탈요금 할인까지!&lt/em', metadata={'source': '/workspace/data/tmp.csv', 'row': 52}),
#  Document(page_content='카드설명: 실속만점 생활할인은 기본!&lt이제 렌탈요금 까지 할인 받자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 53}),
#  Document(page_content='카드설명: GS25할인 5%, T머니 10% 할인 서비스', metadata={'source': '/workspace/data/tmp.csv', 'row': 54}),
#  Document(page_content='카드설명: 2자녀 이상을 둔 가정에게 드리는&lt최대 특혜를 누리세요~!', metadata={'source': '/workspace/data/tmp.csv', 'row': 55}),
#  Document(page_content='카드설명: 유가보조금 받고!&lt GS칼텍스 주유 할인까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 56}),
#  Document(page_content='카드설명: 유가보조금 + 정유3사 주유할인을&lt 카드의정석 화물복지카드 한장으로!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 57}),
#  Document(page_content='카드설명: 전월실적 조건 없이 S-OIL 화물차우대주유소에서 주유 시 리터당 최대 50원 현장할인 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 58}),
#  Document(page_content='카드설명: 전월실적 조건 없이 SK 내트럭플러스에서 주유 시 리터당 최대 50원 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 59}),
#  Document(page_content='카드설명: S-OIL 주유소 리터당 120~400원 할인 서비스에 다양한 생활 &lt/ 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 60}),
#  Document(page_content='카드설명: LPG 화물차 유가보조금 지원, E1 충전소 결제금액 1천원당 오렌지포인트 최대 30P 적립, 다양한 생활서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 61}),
#  Document(page_content='카드설명: SK주유소 리터당 120~400원 할인에&lt / 다양한 생활 혜택까지 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 62}),
#  Document(page_content='카드설명: Auto 금융 할인 및 자동차 특화서비스에 다양한 생활 할인 혜택까지', metadata={'source': '/workspace/data/tmp.csv', 'row': 63}),
#  Document(page_content='카드설명: 자동차 연비를 높이는 새로운 답을 제시하다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 64}),
#  Document(page_content='카드설명: 에코라서 가능한 혜택, 에코로 쌓는 더 많은 포인트', metadata={'source': '/workspace/data/tmp.csv', 'row': 65}),
#  Document(page_content='카드설명: 건설기계 사업자의 성공 인프라!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 66}),
#  Document(page_content='카드설명: 할인혜택으로 레저의 즐거움이&lt/더욱 커진다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 67}),
#  Document(page_content='카드설명: LG U+ 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 68}),
#  Document(page_content='카드설명: 너겟 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 69}),
#  Document(page_content='카드설명: SKT 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 70}),
#  Document(page_content='카드설명: KT 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 71}),
#  Document(page_content='카드설명: KT 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 72}),
#  Document(page_content='카드설명: LG U+ 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 73}),
#  Document(page_content='카드설명: U+알뜰폰 통신요금 할인 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 74}),
#  Document(page_content='카드설명: KT 알뜰폰 통신요금 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 75}),
#  Document(page_content='카드설명: 통신요금 할인에 다양한 할인 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 76}),
#  Document(page_content='카드설명: 유가보조금 + 정유3사 주유할인, &lt우리 썸화물복지카드 단 한장으로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 77}),
#  Document(page_content='카드설명: 국방 가족을 위한 특별한 혜택을 담은 카드!&lt /군복지시설, 생활밀착형 할인 등 다양한 할인을 누리세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 78}),
#  Document(page_content='카드설명: 군인연금수급자임을 증명하는 신분증 기능에 전국 군복지시설 및 5대 대표업종 청구할인, 버스요금 지원서비스', metadata={'source': '/workspace/data/tmp.csv', 'row': 79}),
#  Document(page_content='카드설명: 국민연금수급자임을 증명하는 신분증 기능에 버스요금 매달 최대 5천원 지원과 다양한 카드 혜택 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 80}),
#  Document(page_content='카드설명: 환경부 에코 프로젝트~ 그린을 꺼내세요!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 81}),
#  Document(page_content='카드설명: 환경부 에코 프로젝트~ 그린을 꺼내세요!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 82}),
#  Document(page_content='카드설명: 전국 어디서나 대중교통 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 83}),
#  Document(page_content='카드설명: 패밀리니까! 더 받는다! 생활에 필요한 다양한 실속 할인혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 84}),
#  Document(page_content='카드설명: 패밀리니까! 더 받는다! 생활에 필요한 다양한 실속 할인혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 85}),
#  Document(page_content='카드설명: 국기원 단증에 카드를 결합한 태권도인 특화 상품', metadata={'source': '/workspace/data/tmp.csv', 'row': 86}),
#  Document(page_content='카드설명: 세례명카드 만들고 자동기부도 하고 다양한 혜택도 누리면서 적립된 포인트는 교구에 기부됩니다.', metadata={'source': '/workspace/data/tmp.csv', 'row': 87}),
#  Document(page_content='카드설명: 적립된 상환용 적립 포인트를 자녀의 학자금 대출 원리금 상환에 활용하며, 기타 다양한 혜택을 누리세요~', metadata={'source': '/workspace/data/tmp.csv', 'row': 88}),
#  Document(page_content='카드설명: 우리은행 주거래고객님을 위한 특별한 혜택! &lt /국내 모든 가맹점에서 0.5~1.5% 적립,&lt/6개월마다 15,000점 보너스 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 89}),
#  Document(page_content='카드설명: 우리은행 주거래고객님을 위한 특별한 혜택! &lt /국내 모든 가맹점에서 0.5~1.5% 적립,&lt/6개월마다 15,000점 보너스 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 90}),
#  Document(page_content='카드설명: 카드 한 장으로 신용카드 혜택과 &lt/한화그룹 계열사 서비스를 한번에 해결하자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 91}),
#  Document(page_content='카드설명: 카드 한 장으로 신용카드 혜택과 &lt/한화그룹 계열사 서비스를 한번에 해결하자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 92}),
#  Document(page_content='카드설명: 회사에 반했다! kt 그룹이 좋아졌다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 93}),
#  Document(page_content='카드설명: 모든 백화점, 대형마트, 병원, 서점에서 우리V카드만 있으면 365일 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 94}),
#  Document(page_content='카드설명: woori 할인서비스, 패밀리레스토랑 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 95}),
#  Document(page_content='카드설명: 항공 마일리지 적립서비스, 주유, 놀이공원 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 96}),
#  Document(page_content='카드설명: 한국플랫폼 프리랜서 노동공제회 제휴 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 97}),
#  Document(page_content='카드설명: 우리카드와 L.POINT가 만나다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 98}),
#  Document(page_content='카드설명: 프리미엄의 혜택을 체크카드에 그대로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 99}),
#  Document(page_content='카드설명: 한국장애인고용공단 제휴카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 100}),
#  Document(page_content='카드설명: 쿠키처럼 달콤한 혜택이 쏟아진다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 101}),
#  Document(page_content='카드설명: 쿠키처럼 달콤한 혜택이 쏟아진다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 102}),
#  Document(page_content='카드설명: 사용할 때 마다 커지는 적립혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 103}),
#  Document(page_content='카드설명: 우리카드×광복회', metadata={'source': '/workspace/data/tmp.csv', 'row': 104}),
#  Document(page_content='카드설명: UniMile 하나로 6대 항공사 모두 OK!, 카드의 정석 UniMile CHECK', metadata={'source': '/workspace/data/tmp.csv', 'row': 105}),
#  Document(page_content='카드설명: 적립 포인트로 학자금 대출 원리금 상환에 활용도하고 다양한 혜택을 누리세요~', metadata={'source': '/workspace/data/tmp.csv', 'row': 106}),
#  Document(page_content='카드설명: 에너지도 Eco하고 카드사용도 Eco하는 에코마일리지우리체크카드!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 107}),
#  Document(page_content='카드설명: 출근은 편하게, 교통비는 가볍게! &lt 마일리지로 더 알뜰하게~', metadata={'source': '/workspace/data/tmp.csv', 'row': 108}),
#  Document(page_content='카드설명: 아파트 관리비 혜택을 담다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 109}),
#  Document(page_content='카드설명: 외국인 고객을 위한 맞춤형 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 110}),
#  Document(page_content='카드설명: CJ ONE 멤버십 혜택은 기본, 프리미엄의 혜택을 체크카드에 그대로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 111}),
#  Document(page_content='카드설명: 학생증 한장으로 다양한 캐시백과 멀티 멤버십 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 112}),
#  Document(page_content='카드설명: 편의점 커피 학원 할인과 함께 신나는 대학생활!', metadata={'source': '/workspace/data/tmp.csv', 'row': 113}),
#  Document(page_content='카드설명: 현대백화점ㆍ현대아울렛ㆍ진에어 할인부터 각종 생활할인 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 114}),
#  Document(page_content='카드설명: 해외 이용 수수료 면제 및 이용금액 1~2% 캐시백', metadata={'source': '/workspace/data/tmp.csv', 'row': 115}),
#  Document(page_content='카드설명: [가득한 체크] 협약된 교구, 성당, 세례명 등이 인자된 나만의 성당체크카드를 발급받아 가득한 혜택을 누리세요', metadata={'source': '/workspace/data/tmp.csv', 'row': 116}),
#  Document(page_content='카드설명: 군인연금수급자임을 증명하는 신분증 기능에 버스요금 지원서비스 및 다양한 생활밀착형 서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 117}),
#  Document(page_content='카드설명: 카드 한 장으로 체크카드 혜택과 &lt/한화그룹 계열사 서비스를 한번에 해결하자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 118}),
#  Document(page_content='카드설명: 국민연금수급자임을 증명하는 신분증 기능에 버스요금 매달 최대 5천원과 다양한 카드 혜택 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 119}),
#  Document(page_content='카드설명: GS25할인 5%, T머니 10% 할인 서비스', metadata={'source': '/workspace/data/tmp.csv', 'row': 120}),
#  Document(page_content='카드설명: GS25에서 5% 할인 , T머니 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 121}),
#  Document(page_content='카드설명: 스타벅스, 커피빈 20%, GS25할인 5%, T-money 충전시 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 122}),
#  Document(page_content='카드설명: 이젠 유가보조금도 우리카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 123}),
#  Document(page_content='카드설명: 2자녀 이상을 둔 가정에게 드리는&lt최대 특혜를 누리세요~!', metadata={'source': '/workspace/data/tmp.csv', 'row': 124}),
#  Document(page_content='카드설명: 국내에서는 원화로, 해외에서는 외화로 바로 출금!', metadata={'source': '/workspace/data/tmp.csv', 'row': 125}),
#  Document(page_content='카드설명: 해외에서 현금이 필요할때? 난 저렴하게 찾는다! 해외ATM 이용 특화 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 126}),
#  Document(page_content='카드설명: Special Benefits~ Enjoy 우리V외국인체크카드! 외국인을 위한 실용적인 서비스가 가득', metadata={'source': '/workspace/data/tmp.csv', 'row': 127}),
#  Document(page_content='카드설명: 해외에서도 국내에서도 국제학생증 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 128}),
#  Document(page_content='카드설명: Color your Spring', metadata={'source': '/workspace/data/tmp.csv', 'row': 129}),
#  Document(page_content='카드설명: 도토리들을 위해 준비했어', metadata={'source': '/workspace/data/tmp.csv', 'row': 130}),
#  Document(page_content='카드설명: Global citizen in the universe', metadata={'source': '/workspace/data/tmp.csv', 'row': 131}),
#  Document(page_content='카드설명: 전가맹점 혜택은 기본! 내 취향 가득 담은 나만의 플레이리스트', metadata={'source': '/workspace/data/tmp.csv', 'row': 132}),
#  Document(page_content='카드설명: 전가맹점 혜택은 기본! 내 취향 가득 담은 나만의 플레이리스트', metadata={'source': '/workspace/data/tmp.csv', 'row': 133}),
#  Document(page_content='카드설명: 반복되는 일상부터 나를 위한 소비까지! 데이터로 찾은 내 소비의 핏', metadata={'source': '/workspace/data/tmp.csv', 'row': 134}),
#  Document(page_content='카드설명: 만 12세 이상 미성년 가족 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 135}),
#  Document(page_content='카드설명: EVerywhere we drive', metadata={'source': '/workspace/data/tmp.csv', 'row': 136}),
#  Document(page_content='카드설명: 이츠 모아 태산! 먹을수록(Eats) 혜택을 더 모아(More)', metadata={'source': '/workspace/data/tmp.csv', 'row': 137}),
#  Document(page_content='카드설명: 이츠 모아 태산! 먹을수록(Eats) 혜택을 더 모아(More)', metadata={'source': '/workspace/data/tmp.csv', 'row': 138}),
#  Document(page_content='카드설명: This card will make you smile', metadata={'source': '/workspace/data/tmp.csv', 'row': 139}),
#  Document(page_content='카드설명: Catch me in the moment!', metadata={'source': '/workspace/data/tmp.csv', 'row': 140}),
#  Document(page_content='카드설명: Smart한 구독 Life!', metadata={'source': '/workspace/data/tmp.csv', 'row': 141}),
#  Document(page_content='카드설명: 나의 슬기로운 Pay 생활!', metadata={'source': '/workspace/data/tmp.csv', 'row': 142}),
#  Document(page_content='카드설명: 알뜰폰 요금, 더 알뜰히 모으자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 143}),
#  Document(page_content='카드설명: All Things for Fans', metadata={'source': '/workspace/data/tmp.csv', 'row': 144}),
#  Document(page_content='카드설명: 속 깊은 주유혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 145}),
#  Document(page_content='카드설명: 수소차 충전요금 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 146}),
#  Document(page_content='카드설명: 탈 수록 즐겁고, 탈 수록 득이 되는', metadata={'source': '/workspace/data/tmp.csv', 'row': 147}),
#  Document(page_content='카드설명: 1.5배 높은 적립! 해외는 더블 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 148}),
#  Document(page_content='카드설명: 어떤 차를 구매하든 MY CAR는 신한카드 MY CAR로~', metadata={'source': '/workspace/data/tmp.csv', 'row': 149}),
#  Document(page_content='카드설명: 정부에서 지원하는 국가바우처를 한장의 카드로 이용하세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 150}),
#  Document(page_content='카드설명: 개인사업자를 위한 IKEA 할인 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 151}),
#  Document(page_content='카드설명: 신나는 나의 Home Life, YaY(예~이!)', metadata={'source': '/workspace/data/tmp.csv', 'row': 152}),
#  Document(page_content='카드설명: 만 12세 이상 미성년 가족 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 153}),
#  Document(page_content='카드설명: 모든 주유소 포인트 적립에 생활 맞춤 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 154}),
#  Document(page_content='카드설명: 1천원당 대한항공 1마일 적립 항공/면세/해외 2배 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 155}),
#  Document(page_content='카드설명: 제주혜택 한데 모아, 모두 모아', metadata={'source': '/workspace/data/tmp.csv', 'row': 156}),
#  Document(page_content='카드설명: 너도 살고 나도 사는 우리동네 배달앱 땡겨요', metadata={'source': '/workspace/data/tmp.csv', 'row': 157}),
#  Document(page_content='카드설명: 속 깊은 디지털 라이프', metadata={'source': '/workspace/data/tmp.csv', 'row': 158}),
#  Document(page_content='카드설명: 속 깊은 혜택을 더한!', metadata={'source': '/workspace/data/tmp.csv', 'row': 159}),
#  Document(page_content='카드설명: 생활쇼핑 가맹점 최대 15% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 160}),
#  Document(page_content='카드설명: 내가 직접 선택하는 나만의 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 161}),
#  Document(page_content='카드설명: 자동으로 챙겨주는 나만의 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 162}),
#  Document(page_content='카드설명: 간편결제(Pay) 서비스는 Deep On!', metadata={'source': '/workspace/data/tmp.csv', 'row': 163}),
#  Document(page_content='카드설명: 한번으로 누려라!', metadata={'source': '/workspace/data/tmp.csv', 'row': 164}),
#  Document(page_content='카드설명: 한번으로 누려라!', metadata={'source': '/workspace/data/tmp.csv', 'row': 165}),
#  Document(page_content='카드설명: 할인율을 내 마음대로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 166}),
#  Document(page_content='카드설명: 매일매일 가는 길마다 신한카드 교통 Big 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 167}),
#  Document(page_content='카드설명: Essential For Every Lifestyle', metadata={'source': '/workspace/data/tmp.csv', 'row': 168}),
#  Document(page_content='카드설명: 잘 가는 곳 1~5% 적립 어디서나 0.2~2% 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 169}),
#  Document(page_content='카드설명: 전월 실적 없이 0.7% 캐시백!', metadata={'source': '/workspace/data/tmp.csv', 'row': 170}),
#  Document(page_content='카드설명: 언제 어디서나 특별한 쇼핑의 순간!', metadata={'source': '/workspace/data/tmp.csv', 'row': 171}),
#  Document(page_content='카드설명: 생활비 혜택을 가득 담은 서민금융지원카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 172}),
#  Document(page_content='카드설명: 부모마음을 잘 아는 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 173}),
#  Document(page_content='카드설명: 나의 금융파트너! 신한 주거래 패키지로 더 많은 혜택을!', metadata={'source': '/workspace/data/tmp.csv', 'row': 174}),
#  Document(page_content='카드설명: 항공 마일리지에 포인트, 프리미엄 서비스까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 175}),
#  Document(page_content='카드설명: 맹모카드지교! 우리아이 레슨 받는 곳이라면 어디든지', metadata={'source': '/workspace/data/tmp.csv', 'row': 176}),
#  Document(page_content='카드설명: 전월 실적 없이 1% 캐시백!', metadata={'source': '/workspace/data/tmp.csv', 'row': 177}),
#  Document(page_content='카드설명: 선택 서비스 10개 중 5개, 5% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 178}),
#  Document(page_content='카드설명: 할인, 적립에 플래티늄 서비스까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 179}),
#  Document(page_content='카드설명: Shine카드의 빛나는 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 180}),
#  Document(page_content='카드설명: 부담없는 연회비로, 교체없이 10년동안 쭈욱!', metadata={'source': '/workspace/data/tmp.csv', 'row': 181}),
#  Document(page_content='카드설명: 부담없는 연회비로, 교체없이 10년동안 쭈욱!', metadata={'source': '/workspace/data/tmp.csv', 'row': 182}),
#  Document(page_content='카드설명: 속 깊은 주유혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 183}),
#  Document(page_content='카드설명: 한장의 카드로 6대 홈쇼핑 6% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 184}),
#  Document(page_content='카드설명: 주는 행복, 받는 기쁨! 아름다운 당신의 아름다운 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 185}),
#  Document(page_content='카드설명: 보육료 지원금 결제와 할인서비스 혜택까지!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 186}),
#  Document(page_content='카드설명: 550만 오너를 위한 맞춤혜택 제공!', metadata={'source': '/workspace/data/tmp.csv', 'row': 187}),
#  Document(page_content='카드설명: 최대 2% LPG 충전 혜택과 생활 할인을 동시에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 188}),
#  Document(page_content='카드설명: 속 깊은 당신을 위한 경차사랑 Life', metadata={'source': '/workspace/data/tmp.csv', 'row': 189}),
#  Document(page_content='카드설명: 세무지원, 사업경비 포인트 적립 혜택까지!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 190}),
#  Document(page_content='카드설명: 전기차 LIFE를 누려보세요. 전기차 충전요금 30~50% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 191}),
#  Document(page_content='카드설명: 세무지원, 사업경비 포인트 적립 혜택까지!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 192}),
#  Document(page_content='카드설명: 매일매일 가는 길마다 신한카드 교통 Big 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 193}),
#  Document(page_content='카드설명: 사업자를 위한 부가세 서비스!', metadata={'source': '/workspace/data/tmp.csv', 'row': 194}),
#  Document(page_content='카드설명: 주택임대료 할인과 생활 할인 중 선택하여 발급받으세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 195}),
#  Document(page_content='카드설명: 국세청 임직원 복지 증진을 위한 복지카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 196}),
#  Document(page_content='카드설명: 국세청 임직원 복지 증진을 위한 복지카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 197}),
#  Document(page_content='카드설명: 복지포인트도 생활비 할인도 하나의 카드로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 198}),
#  Document(page_content='카드설명: 복지포인트도 적립혜택도 하나의 카드로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 199}),
#  Document(page_content='카드설명: LPG 할인 + 무임교통카드 + 고속도로 통행료 감면 서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 200}),
#  Document(page_content='카드설명: LPG 할인 + 무임교통카드 + 고속도로 통행료 감면 서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 201}),
#  Document(page_content='카드설명: Shopping에 교원증을 더하다', metadata={'source': '/workspace/data/tmp.csv', 'row': 202}),
#  Document(page_content='카드설명: Registered Nurse CARD', metadata={'source': '/workspace/data/tmp.csv', 'row': 203}),
#  Document(page_content='카드설명: 앞서가는 여성의 필수품, Lady카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 204}),
#  Document(page_content='카드설명: 더 이상의 카드는 없다. 신개념의 주유 서비스를 경험해 보세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 205}),
#  Document(page_content='카드설명: 가볍고 편해지는 발걸음! 대중교통 요금 10%할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 206}),
#  Document(page_content='카드설명: 현장에서 바로 받는 주유 할인 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 207}),
#  Document(page_content='카드설명: 화물운전자복지 카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 208}),
#  Document(page_content='카드설명: SK에너지 2MORE 화물복지카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 209}),
#  Document(page_content='카드설명: 알뜰주유소 화물복지카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 210}),
#  Document(page_content='카드설명: HD현대오일뱅크 2UP 화물복지카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 211}),
#  Document(page_content='카드설명: S-OIL 2UP 화물복지카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 212}),
#  Document(page_content='카드설명: 사업경비 결제하고 포인트도 쌓고! 주유, 병원/약국, 대중교통 할인까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 213}),
#  Document(page_content='카드설명: 편리한 유가보조금 지원과 강화된 포인트 적립 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 214}),
#  Document(page_content='카드설명: S.Sing 씽 화물복지카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 215}),
#  Document(page_content='카드설명: 내 사업의 비용절감을 위한 완벽한 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 216}),
#  Document(page_content='카드설명: 교직원공제회원의 알뜰소비생활 필수카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 217}),
#  Document(page_content='카드설명: 한수원 복지포인트 이용에 할인, 포인트 적립까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 218}),
#  Document(page_content='카드설명: 화물 유가보조금+주유할인 서비스까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 219}),
#  Document(page_content='카드설명: 부산시의 다자녀가정 지원 가족사랑 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 220}),
#  Document(page_content='카드설명: iPhone for Life', metadata={'source': '/workspace/data/tmp.csv', 'row': 221}),
#  Document(page_content='카드설명: Time For us to Shine', metadata={'source': '/workspace/data/tmp.csv', 'row': 222}),
#  Document(page_content='카드설명: SPOTV NOW를 즐기는 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 223}),
#  Document(page_content='카드설명: CJ ONE 포인트 매니아를 위한 특권!', metadata={'source': '/workspace/data/tmp.csv', 'row': 224}),
#  Document(page_content='카드설명: 알파포인트로 누리는 새로운 투자경험!', metadata={'source': '/workspace/data/tmp.csv', 'row': 225}),
#  Document(page_content='카드설명: KT 휴대폰 할부에 통신요금 할인까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 226}),
#  Document(page_content='카드설명: 신세계사이먼 프리미엄 아울렛 최대 10% 결제일 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 227}),
#  Document(page_content='카드설명: 신세계사이먼 프리미엄 아울렛 최대 10% 결제일 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 228}),
#  Document(page_content='카드설명: Kakaopay Pick', metadata={'source': '/workspace/data/tmp.csv', 'row': 229}),
#  Document(page_content='카드설명: 건프라와 피규어를 마음껏!', metadata={'source': '/workspace/data/tmp.csv', 'row': 230}),
#  Document(page_content='카드설명: 보험료 할인과 함께 의료, 헬스, 생활편의 할인 서비스를 한번에', metadata={'source': '/workspace/data/tmp.csv', 'row': 231}),
#  Document(page_content='카드설명: LG트윈스 홈경기 응원하러 야구장 갈땐~ 필수템!', metadata={'source': '/workspace/data/tmp.csv', 'row': 232}),
#  Document(page_content='카드설명: T 멤버십 고객의 필수템!', metadata={'source': '/workspace/data/tmp.csv', 'row': 233}),
#  Document(page_content='카드설명: 아이와 엄마를 위한 현명한 선택', metadata={'source': '/workspace/data/tmp.csv', 'row': 234}),
#  Document(page_content='카드설명: 프레딧 멤버십을 위한 완벽한 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 235}),
#  Document(page_content='카드설명: 30% 할인, 사이즈업 쿠폰에 대중교통 생활혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 236}),
#  Document(page_content='카드설명: 제주신화월드 객실 최대 15% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 237}),
#  Document(page_content='카드설명: 쓸 때마다 쌓이는 GS&POINT!', metadata={'source': '/workspace/data/tmp.csv', 'row': 238}),
#  Document(page_content='카드설명: 모두의 구독 유니버스, T우주', metadata={'source': '/workspace/data/tmp.csv', 'row': 239}),
#  Document(page_content='카드설명: 스마트하게 IKEA를 즐기는 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 240}),
#  Document(page_content='카드설명: 오아시스 새벽배송 15% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 241}),
#  Document(page_content='카드설명: 뷰티포인트 적립 혜택을 누리세요', metadata={'source': '/workspace/data/tmp.csv', 'row': 242}),
#  Document(page_content='카드설명: 맛있는 생활의 필수 혜택 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 243}),
#  Document(page_content='카드설명: 간편 결제의 새로운 기준 L.PAY!', metadata={'source': '/workspace/data/tmp.csv', 'row': 244}),
#  Document(page_content='카드설명: LG헬로비전 요금 (케이블방송, 인터넷, 알뜰폰-헬로모바일 등) 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 245}),
#  Document(page_content='카드설명: 실적조건과 적립한도에 제한이 없는 네이버페이 포인트 특화카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 246}),
#  Document(page_content='카드설명: 맞춤형 복지포인트 사용 및 iMND Light의 산뜻한 혜택을 누리세요', metadata={'source': '/workspace/data/tmp.csv', 'row': 247}),
#  Document(page_content='카드설명: 최대 60개월 장기 할부와 매월 최대 1만 5천원 캐시백 혜택까지', metadata={'source': '/workspace/data/tmp.csv', 'row': 248}),
#  Document(page_content='카드설명: 새로운 모빌리티, 더 커진 금융 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 249}),
#  Document(page_content='카드설명: 홈플러스 포인트 1.2%적립(점외 이용시 0.5%적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 250}),
#  Document(page_content='카드설명: 쉽고 편한 모바일 쇼핑 세상 편한 11PAY 결제!', metadata={'source': '/workspace/data/tmp.csv', 'row': 251}),
#  Document(page_content='카드설명: 신세계백화점 멤버십 혜택, 신세계백화점 5% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 252}),
#  Document(page_content='카드설명: 신세계백화점 멤버십 혜택 항공마일리지 기본/추가 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 253}),
#  Document(page_content='카드설명: 신세계백화점 최대 7% 결제일 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 254}),
#  Document(page_content='카드설명: 신세계사이먼 프리미엄 아울렛 최대 10% 결제일 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 255}),
#  Document(page_content='카드설명: 신세계백화점 멤버십 혜택, 신세계백화점 5% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 256}),
#  Document(page_content='카드설명: 스마트 가격! 맛있는 더본 브랜드는 신한카드와 함께!', metadata={'source': '/workspace/data/tmp.csv', 'row': 257}),
#  Document(page_content='카드설명: 모바일 Tmoney App 이용 시 20%할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 258}),
#  Document(page_content='카드설명: 전가맹점 최대 0.6% 적립 및 전구단 야구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 259}),
#  Document(page_content='카드설명: 월 최대 1만 5천원 통신요금 할인 및 다양한 제휴 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 260}),
#  Document(page_content='카드설명: SOCAR 결제 시 30% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 261}),
#  Document(page_content='카드설명: 전자책 서점 리디북스 20% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 262}),
#  Document(page_content='카드설명: LG전자 가전제품 알뜰하게 구매하자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 263}),
#  Document(page_content='카드설명: 전월실적 조건 없이 어디서든 적립되는 온라인 쇼핑', metadata={'source': '/workspace/data/tmp.csv', 'row': 264}),
#  Document(page_content='카드설명: 전월실적, 적립한도 없는 네이버페이 포인트적립혜택을 누려보세요', metadata={'source': '/workspace/data/tmp.csv', 'row': 265}),
#  Document(page_content='카드설명: 다이소 30%, 생활 10%, 영화 20% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 266}),
#  Document(page_content='카드설명: 메가마트 포인트 1.5% 적립(점외 이용 시 0.5% 적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 267}),
#  Document(page_content='카드설명: 레일리지 쌓고 SRT 이용시 혜택 받으세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 268}),
#  Document(page_content='카드설명: 차곡차곡 항공 포인트 쌓고, 내맘대로 쉽게 꺼내 쓰자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 269}),
#  Document(page_content='카드설명: 속 깊은 주유혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 270}),
#  Document(page_content='카드설명: 멋을 아는 남성의 선택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 271}),
#  Document(page_content='카드설명: 안심에 할인을 더하다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 272}),
#  Document(page_content='카드설명: LF SQUARE 매장 할인카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 273}),
#  Document(page_content='카드설명: LG U+ 통신요금(전화, 인터넷, TV 등) 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 274}),
#  Document(page_content='카드설명: Gold할부 이용하고, 통신요금 할인 받으세요', metadata={'source': '/workspace/data/tmp.csv', 'row': 275}),
#  Document(page_content='카드설명: 월 최대 4만 2천원 통신요금 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 276}),
#  Document(page_content='카드설명: U+ 통신요금에 할인을 Plus!', metadata={'source': '/workspace/data/tmp.csv', 'row': 277}),
#  Document(page_content='카드설명: KT 통신요금에 할인을 Plus!', metadata={'source': '/workspace/data/tmp.csv', 'row': 278}),
#  Document(page_content='카드설명: 라이트할부로 통신요금도 라이트하게!', metadata={'source': '/workspace/data/tmp.csv', 'row': 279}),
#  Document(page_content='카드설명: 이제 홈플러스에서 최대 7% 적립 받으세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 280}),
#  Document(page_content='카드설명: 탑보너스포인트 최대 2.5% 적립(점외 이용 시 0.5% 적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 281}),
#  Document(page_content='카드설명: 탑보너스포인트 최대 2.0% 적립(점외 이용 시 0.5% 적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 282}),
#  Document(page_content='카드설명: LG베스트샵 장기할부카드로 가전제품 알뜰하게 구입하세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 283}),
#  Document(page_content='카드설명: 귀여운 라이언 대박 예감', metadata={'source': '/workspace/data/tmp.csv', 'row': 284}),
#  Document(page_content='카드설명: 귀여운 춘식이 대박 예감', metadata={'source': '/workspace/data/tmp.csv', 'row': 285}),
#  Document(page_content='카드설명: 너! 내 동료가 돼라!', metadata={'source': '/workspace/data/tmp.csv', 'row': 286}),
#  Document(page_content='카드설명: 이 세상에 고칠 수 없는 병은 없으니깐!', metadata={'source': '/workspace/data/tmp.csv', 'row': 287}),
#  Document(page_content='카드설명: 맹구가 카드 안에 들어왔다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 288}),
#  Document(page_content='카드설명: 오수가 카드 안에 들어왔다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 289}),
#  Document(page_content='카드설명: 오밀조밀 깨댕이가 카드에 들어왔다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 290}),
#  Document(page_content='카드설명: 안녕 내이름은 눙눙이야', metadata={'source': '/workspace/data/tmp.csv', 'row': 291}),
#  Document(page_content='카드설명: 너만의 포켓몬을 Pick 해!', metadata={'source': '/workspace/data/tmp.csv', 'row': 292}),
#  Document(page_content='카드설명: 너만의 포켓몬을 Pick 해!', metadata={'source': '/workspace/data/tmp.csv', 'row': 293}),
#  Document(page_content='카드설명: 여행 갈때도 월리를 찾아라!', metadata={'source': '/workspace/data/tmp.csv', 'row': 294}),
#  Document(page_content='카드설명: 미니언즈가 시원하게 적립해드립니다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 295}),
#  Document(page_content='카드설명: 도토리들을 위해 준비했어', metadata={'source': '/workspace/data/tmp.csv', 'row': 296}),
#  Document(page_content='카드설명: E들은 이 카드를 픽하지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 297}),
#  Document(page_content='카드설명: 혜택도 내성적일 거란 편견은 버려~', metadata={'source': '/workspace/data/tmp.csv', 'row': 298}),
#  Document(page_content='카드설명: 카드에 박힌 나.. 쫌 귀여울수도?', metadata={'source': '/workspace/data/tmp.csv', 'row': 299}),
#  Document(page_content='카드설명: 끝이 없는 할인 구독 서비스', metadata={'source': '/workspace/data/tmp.csv', 'row': 300}),
#  Document(page_content='카드설명: 국내/해외 판타스틱한 혜택에 신한플레이 캐시백까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 301}),
#  Document(page_content='카드설명: 카드는 원래 꺾이지 않는 거 알지?', metadata={'source': '/workspace/data/tmp.csv', 'row': 302}),
#  Document(page_content='카드설명: 무적 LG! 끝까지 TWINS! 직관 할인과 실생활 혜택까지', metadata={'source': '/workspace/data/tmp.csv', 'row': 303}),
#  Document(page_content='카드설명: 내 얼굴이 담긴 카드를 가지고 싶지 않니?', metadata={'source': '/workspace/data/tmp.csv', 'row': 304}),
#  Document(page_content='카드설명: 전 가맹점에서 적립되는 GS&POINT!', metadata={'source': '/workspace/data/tmp.csv', 'row': 305}),
#  Document(page_content='카드설명: Color your Spring', metadata={'source': '/workspace/data/tmp.csv', 'row': 306}),
#  Document(page_content='카드설명: 전가맹점 혜택은 기본! 내 취향 가득 담은 나만의 플레이리스트', metadata={'source': '/workspace/data/tmp.csv', 'row': 307}),
#  Document(page_content='카드설명: 전가맹점 혜택은 기본! 내 취향 가득 담은 나만의 플레이리스트', metadata={'source': '/workspace/data/tmp.csv', 'row': 308}),
#  Document(page_content='카드설명: 간편결제와 생활편의 영역까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 309}),
#  Document(page_content='카드설명: 간편결제와 생활편의 영역까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 310}),
#  Document(page_content='카드설명: 대중교통과 생활편의 영역까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 311}),
#  Document(page_content='카드설명: 대중교통과 생활편의 영역까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 312}),
#  Document(page_content='카드설명: 너도 살고 나도 사는 우리동네 배달앱 땡겨요', metadata={'source': '/workspace/data/tmp.csv', 'row': 313}),
#  Document(page_content='카드설명: 너도 살고 나도 사는 우리동네 배달앱 땡겨요', metadata={'source': '/workspace/data/tmp.csv', 'row': 314}),
#  Document(page_content='카드설명: 20% 캐시백, 사이즈업 쿠폰에 OTT 캐시백 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 315}),
#  Document(page_content='카드설명: 체크카드도 뷰티포인트 적립 혜택을!', metadata={'source': '/workspace/data/tmp.csv', 'row': 316}),
#  Document(page_content='카드설명: 핀크머니 0.2% 적립(월 최대1만원)', metadata={'source': '/workspace/data/tmp.csv', 'row': 317}),
#  Document(page_content='카드설명: 전월실적 조건없이 사용횟수별 최대 2만원 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 318}),
#  Document(page_content='카드설명: 간편 결제의 새로운 기준 L.PAY!', metadata={'source': '/workspace/data/tmp.csv', 'row': 319}),
#  Document(page_content='카드설명: 유가보조금 지원과 포인트 적립 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 320}),
#  Document(page_content='카드설명: 정부에서 지원하는 국가바우처를 한장의 카드로 이용하세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 321}),
#  Document(page_content='카드설명: 쓸수록 쌓이는 포인트, 신한 플러스 멤버십 체크카드로 더 많은 혜택을!', metadata={'source': '/workspace/data/tmp.csv', 'row': 322}),
#  Document(page_content='카드설명: 카드 덕후가 연구 했어요. 버릴 혜택이 없는 체크카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 323}),
#  Document(page_content='카드설명: Global+ 서비스에 신한투자증권 우대서비스까지~!', metadata={'source': '/workspace/data/tmp.csv', 'row': 324}),
#  Document(page_content='카드설명: 대한항공 마일리지 적립 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 325}),
#  Document(page_content='카드설명: 아시아나항공 마일리지 적립 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 326}),
#  Document(page_content='카드설명: 해외 특화 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 327}),
#  Document(page_content='카드설명: 어디서나 0.2% 적립, 선택한 곳에서 5배 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 328}),
#  Document(page_content='카드설명: 어디서나 0.2% 적립, 선택한 곳에서 5배 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 329}),
#  Document(page_content='카드설명: 부모와 자녀를 위한 스마트한 용돈관리 시작', metadata={'source': '/workspace/data/tmp.csv', 'row': 330}),
#  Document(page_content='카드설명: 고속도로요금 결제를 편리하게!', metadata={'source': '/workspace/data/tmp.csv', 'row': 331}),
#  Document(page_content='카드설명: 국내/해외 판타스틱한 혜택에 신한플레이 캐시백까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 332}),
#  Document(page_content='카드설명: 속 깊은 디지털 라이프!', metadata={'source': '/workspace/data/tmp.csv', 'row': 333}),
#  Document(page_content='카드설명: 나의 금융파트너! 신한 주거래 패키지로 더 많은 혜택을!', metadata={'source': '/workspace/data/tmp.csv', 'row': 334}),
#  Document(page_content='카드설명: 고속도로요금 결제를 편리하게!', metadata={'source': '/workspace/data/tmp.csv', 'row': 335}),
#  Document(page_content='카드설명: 미니언즈가 다 드림!', metadata={'source': '/workspace/data/tmp.csv', 'row': 336}),
#  Document(page_content='카드설명: 할인+적립+신한금융 서비스까지 한 번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 337}),
#  Document(page_content='카드설명: 카카오페이로 간편하게 결제하고 혜택까지 플러스', metadata={'source': '/workspace/data/tmp.csv', 'row': 338}),
#  Document(page_content='카드설명: 할인+적립+신한금융 서비스까지 한 번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 339}),
#  Document(page_content='카드설명: 할인+적립+신한금융 서비스까지 한 번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 340}),
#  Document(page_content='카드설명: 복잡한 혜택의 서비스는 그만! 대중교통,커피,쇼핑 중 내가 원하는 하나의 서비스에 ALL-in', metadata={'source': '/workspace/data/tmp.csv', 'row': 341}),
#  Document(page_content='카드설명: 할인+적립+신한금융 서비스까지 한 번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 342}),
#  Document(page_content='카드설명: 홈플러스 포인트 0.6%적립(점외 이용시 0.1%적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 343}),
#  Document(page_content='카드설명: 보육비는 물론, 부모님에게 힘이 되는 혜택까지', metadata={'source': '/workspace/data/tmp.csv', 'row': 344}),
#  Document(page_content='카드설명: 신세계백화점의 혜택을 다 모은 맞춤형 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 345}),
#  Document(page_content='카드설명: 스마트한 가격! 맛잇는 더본 브랜드는 신한카드와 함께!', metadata={'source': '/workspace/data/tmp.csv', 'row': 346}),
#  Document(page_content='카드설명: 전기차 LIFE를 누려보세요. 전기차 충전요금 30% 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 347}),
#  Document(page_content='카드설명: 쉽고 편한 모바일 쇼핑, 세상 편한 11PAY 결제!', metadata={'source': '/workspace/data/tmp.csv', 'row': 348}),
#  Document(page_content='카드설명: 한국야쿠르트와 GS리테일의 특별한 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 349}),
#  Document(page_content='카드설명: 전월실적 조건 없이 어디서든 적립되는 온라인 쇼핑', metadata={'source': '/workspace/data/tmp.csv', 'row': 350}),
#  Document(page_content='카드설명: SOCAR 결제시 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 351}),
#  Document(page_content='카드설명: Love 서비스와 전월 실적에 따른 CMA계좌 추가 금리 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 352}),
#  Document(page_content='카드설명: 주유 추가할인 혜택을 더한 경차만의 특권', metadata={'source': '/workspace/data/tmp.csv', 'row': 353}),
#  Document(page_content='카드설명: 요기요 구매금액 15% 할인 커피/편의점 할인까지', metadata={'source': '/workspace/data/tmp.csv', 'row': 354}),
#  Document(page_content='카드설명: 이제 오프라인에서도 네이버페이로~', metadata={'source': '/workspace/data/tmp.csv', 'row': 355}),
#  Document(page_content='카드설명: 해외 직구는 물론 모든 해외 쇼핑을 위한 똑똑한 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 356}),
#  Document(page_content='카드설명: 전가맹점 최대 0.2% 적립 및 전구단 야구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 357}),
#  Document(page_content='카드설명: CJ ONE 멤버십 기능에 신한 체크카드만의 특별한 혜택까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 358}),
#  Document(page_content='카드설명: 다이소 20%, 생활 10%, 영화 20% 캐시백', metadata={'source': '/workspace/data/tmp.csv', 'row': 359}),
#  Document(page_content='카드설명: 쿠팡 이용금액 3% 적립에 스타벅스 이용금액 캐시백까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 360}),
#  Document(page_content='카드설명: 전자책 서점 리디북스 10% 캐시백', metadata={'source': '/workspace/data/tmp.csv', 'row': 361}),
#  Document(page_content='카드설명: 속 깊은 디지털 라이프!', metadata={'source': '/workspace/data/tmp.csv', 'row': 362}),
#  Document(page_content='카드설명: 속 깊은 디지털 라이프!', metadata={'source': '/workspace/data/tmp.csv', 'row': 363}),
#  Document(page_content='카드설명: 꿈을 키우는 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 364}),
#  Document(page_content='카드설명: 해외에서는 달러(USD)로, 국내에서는 원화로 Change!', metadata={'source': '/workspace/data/tmp.csv', 'row': 365}),
#  Document(page_content='카드설명: 난치병 아이들의 꿈을 이뤄주는 기부카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 366}),
#  Document(page_content='카드설명: 국내/해외 판타스틱한 혜택에 FAN페이 캐시백까지!', metadata={'source': '/workspace/data/tmp.csv', 'row': 367}),
#  Document(page_content='카드설명: 속 깊은 디지털 라이프!', metadata={'source': '/workspace/data/tmp.csv', 'row': 368}),
#  Document(page_content='카드설명: KT 통신요금 5천원, GS25 5%, CGV 10% 캐시백', metadata={'source': '/workspace/data/tmp.csv', 'row': 369}),
#  Document(page_content='카드설명: 화물운전자복지 체크카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 370}),
#  Document(page_content='카드설명: LPG 할인 + 무임교통카드 + 고속도로 통행료 감면 서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 371}),
#  Document(page_content='카드설명: LPG 할인 + 무임교통카드 + 고속도로 통행료 감면 서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 372}),
#  Document(page_content='카드설명: S.Sing 씽 화물복지 체크카드로 빠르고 편리하게 유가보조금 지원 받으세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 373}),
#  Document(page_content='카드설명: 알뜰주유소 화물복지 체크카드로 빠르고 편리하게 유가보조금 지원 받으세요 !', metadata={'source': '/workspace/data/tmp.csv', 'row': 374}),
#  Document(page_content='카드설명: 가볍고 편해지는 발걸음~ 대중교통 요금 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 375}),
#  Document(page_content='카드설명: 메가마트 포인트 0.7% 적립(점외 이용 시 0.1% 적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 376}),
#  Document(page_content='카드설명: 스포츠 강좌 이용을 위한 지원금 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 377}),
#  Document(page_content='카드설명: 청소년도 후불교통으로 대중교통을 스마트하고 편리하게 이용하세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 378}),
#  Document(page_content='카드설명: 대중교통, 커피, 쇼핑 중 내가 원하는 하나의 서비스에 ALL-in', metadata={'source': '/workspace/data/tmp.csv', 'row': 379}),
#  Document(page_content='카드설명: 성남시민을 위한 성남사랑상품권 연동 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 380}),
#  Document(page_content='카드설명: 탑보너스포인트 최대 1.2% 적립(점외 이용 시 0.1% 적립)', metadata={'source': '/workspace/data/tmp.csv', 'row': 381}),
#  Document(page_content='카드설명: 복잡한 혜택의 서비스는 그만! 대중교통, 커피, 쇼핑 중 내가 원하는 하나의 서비스에 All-in!', metadata={'source': '/workspace/data/tmp.csv', 'row': 382}),
#  Document(page_content='카드설명: 부산시의 다자녀가정 지원 가족사랑 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 383}),
#  Document(page_content='카드설명: 교원증과 On 체크의 만남', metadata={'source': '/workspace/data/tmp.csv', 'row': 384}),
#  Document(page_content='카드설명: 삼성증권을 이용하시는 고객님의 혜택!!', metadata={'source': '/workspace/data/tmp.csv', 'row': 385}),
#  Document(page_content='카드설명: ID카드와 Hey-Young 체크를 한 장에', metadata={'source': '/workspace/data/tmp.csv', 'row': 386}),
#  Document(page_content='카드설명: ID카드와 Hey-Young 체크를 한 장에', metadata={'source': '/workspace/data/tmp.csv', 'row': 387}),
#  Document(page_content='카드설명: 롯데마트&MAXX 최대 10% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 388}),
#  Document(page_content='카드설명: 결제 방식도 내 취향에 맞게 나를 위한 스마트 라이프', metadata={'source': '/workspace/data/tmp.csv', 'row': 389}),
#  Document(page_content='카드설명: 카드 하나로 누리는 디지털 쇼핑 라이프', metadata={'source': '/workspace/data/tmp.csv', 'row': 390}),
#  Document(page_content='카드설명: 모든 가맹점 1.2% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 391}),
#  Document(page_content='카드설명: 부산/울산/경남 지역 특화 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 392}),
#  Document(page_content='카드설명: 음식점, 배달앱, 커피 60% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 393}),
#  Document(page_content='카드설명: 롯데계열사 7% 롤라머니 적립 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 394}),
#  Document(page_content='카드설명: 주유, 영화, 스트리밍 60% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 395}),
#  Document(page_content='카드설명: 온·오프라인 쇼핑 10% 풍성한 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 396}),
#  Document(page_content='카드설명: 국내외 가맹점 1.2%~2.0% 결제일 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 397}),
#  Document(page_content='카드설명: 실적 조건없이 온·오프라인 전 가맹점 캐시백', metadata={'source': '/workspace/data/tmp.csv', 'row': 398}),
# ...
#  Document(page_content='카드설명: 제주특별자치도 공무직 직원분들께만 드리는 제주은행 카드의 혜...', metadata={'source': '/workspace/data/tmp.csv', 'row': 867}),
#  Document(page_content='카드설명: 제주삼다수 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 868}),
#  Document(page_content='카드설명: 전월 실적 상관없이 월 최대 4천원 캐쉬백!', metadata={'source': '/workspace/data/tmp.csv', 'row': 869}),
#  Document(page_content='카드설명: 축구를 사랑한다면 제주은행 & 제주유나이티드와 함께하세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 870}),
#  Document(page_content='카드설명: 20-30 젊은 세대를 위한 젊은 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 871}),
#  Document(page_content='카드설명: 임신부터 보육료 & 유아학비까지 다양한 국가 바우처와 다양한 ...', metadata={'source': '/workspace/data/tmp.csv', 'row': 872}),
#  Document(page_content='카드설명: 그린을 꺼내세요!! 제주그린체크카드가 다양한 혜택으로 여러분 ...', metadata={'source': '/workspace/data/tmp.csv', 'row': 873}),
#  Document(page_content='카드설명: 연회비 없이 대한항공 마일리지 적립에 5개 온라인몰 할인까지 ...', metadata={'source': '/workspace/data/tmp.csv', 'row': 874}),
#  Document(page_content='카드설명: 한라대학교 재학생을 위한 학생증카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 875}),
#  Document(page_content='카드설명: 원더카드 맞춤혜택 조합 : 병원부터 관리비까지 생활비 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 876}),
#  Document(page_content='카드설명: 실적 조건 없이 골고루 받는 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 877}),
#  Document(page_content='카드설명: 한장에 담은 SK 통신/주유 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 878}),
#  Document(page_content='카드설명: 우리 가족도 반려동물도 행복한 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 879}),
#  Document(page_content='카드설명: 매일의 즐거움을 책임지는 실용적인 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 880}),
#  Document(page_content='카드설명: 쇼핑할 때마다 행복한 플러스 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 881}),
#  Document(page_content='카드설명: 자유롭게 쓰고 받는 플러스 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 882}),
#  Document(page_content='카드설명: # MY WAY(샵 마이웨이)카드출근에서 퇴근까지 나의 하루를 함께하는 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 883}),
#  Document(page_content='카드설명: 페이결제 조건없이 최대 1%청구할인, 구독서비스 50%청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 884}),
#  Document(page_content='카드설명: 에너지 공과금 할인 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 885}),
#  Document(page_content='카드설명: 주중/주말/매일 청구할인 혜택이 되는 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 886}),
#  Document(page_content='카드설명: 카드 연속사용에 따른 우대 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 887}),
#  Document(page_content='카드설명: 카드 연속사용에 따른 우대 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 888}),
#  Document(page_content='카드설명: 국가바우처와 임신/출산 진료비 지원을 한번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 889}),
#  Document(page_content='카드설명: 환경을 생각합니다.', metadata={'source': '/workspace/data/tmp.csv', 'row': 890}),
#  Document(page_content='카드설명: 실적제한없이 어디서나 0.8%/1.8% 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 891}),
#  Document(page_content='카드설명: 반려동물을 위한 사랑 실천법', metadata={'source': '/workspace/data/tmp.csv', 'row': 892}),
#  Document(page_content='카드설명: 현명한 투자를 위한 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 893}),
#  Document(page_content='카드설명: 로마드 구독 요금 자동이체 시 13,000원 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 894}),
#  Document(page_content='카드설명: 국민연금 수급자를 위한 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 895}),
#  Document(page_content='카드설명: 배달앱/택시/생활밀착업종할인까지! 대구 사람이면 대구로', metadata={'source': '/workspace/data/tmp.csv', 'row': 896}),
#  Document(page_content='카드설명: 신용카드와 외화 하나머니의 만남', metadata={'source': '/workspace/data/tmp.csv', 'row': 897}),
#  Document(page_content='카드설명: 1천원당 최대 2마일! 라운지 무료혜택까지', metadata={'source': '/workspace/data/tmp.csv', 'row': 898}),
#  Document(page_content='카드설명: 해외에서 달러(USD)로 결제되는 해외사용 필수템!', metadata={'source': '/workspace/data/tmp.csv', 'row': 899}),
#  Document(page_content='카드설명: 스마트한 마일리지 적립 방법', metadata={'source': '/workspace/data/tmp.csv', 'row': 900}),
#  Document(page_content='카드설명: 스마트한 마일리지 적립 방법', metadata={'source': '/workspace/data/tmp.csv', 'row': 901}),
#  Document(page_content='카드설명: 실적 관계없이, 적립한도 없이 대한항공 마일리지 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 902}),
#  Document(page_content='카드설명: 실적 관계없이, 적립한도 없이 아시아나 마일리지 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 903}),
#  Document(page_content='카드설명: 해외여행/직구족을 위한 MUST HAVE 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 904}),
#  Document(page_content='카드설명: toss에서 하나카드를 만나보세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 905}),
#  Document(page_content='카드설명: 6대 저비용 항공사 통합 마일리지, Mile1 하나로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 906}),
#  Document(page_content='카드설명: 포인트를 현금처럼 쓰는 하나멤버스 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 907}),
#  Document(page_content='카드설명: 포인트를 현금처럼 쓰는 하나멤버스 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 908}),
#  Document(page_content='카드설명: 서민금융진흥원의 보증을 통해 신청 가능한 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 909}),
#  Document(page_content='카드설명: 국내 가맹점 0.7%, 국내 온라인/해외 가맹점 1.7% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 910}),
#  Document(page_content='카드설명: 국내 가맹점 0.7%, 국내 온라인/해외 가맹점 1.7% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 911}),
#  Document(page_content='카드설명: 포인트를 현금처럼 쓰는 하나멤버스 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 912}),
#  Document(page_content='카드설명: 지역쇼핑/주유에서 혜택이 플러스', metadata={'source': '/workspace/data/tmp.csv', 'row': 913}),
#  Document(page_content='카드설명: 포인트를 현금처럼 쓰는 하나멤버스 신용카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 914}),
#  Document(page_content='카드설명: 100만 고객이 선택한 SK의 모든 혜택', metadata={'source': '/workspace/data/tmp.csv', 'row': 915}),
#  Document(page_content='카드설명: 4대 정유할인과 차량정비의 할인혜택이 되는 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 916}),
#  Document(page_content='카드설명: 고속도로 통행료를 이제 간편하게, 쉽게, 빠르게', metadata={'source': '/workspace/data/tmp.csv', 'row': 917}),
#  Document(page_content='카드설명: CHAI에서 하나카드를 만나보세요!', metadata={'source': '/workspace/data/tmp.csv', 'row': 918}),
#  Document(page_content='카드설명: 쓸 수 밖에 없다면, 아껴라', metadata={'source': '/workspace/data/tmp.csv', 'row': 919}),
#  Document(page_content='카드설명: 1500원당 1 대한항공 마일리지 적립, 바우처 서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 920}),
#  Document(page_content='카드설명: 1500원당 1 대한항공 마일리지 적립, 바우처 서비스 2종 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 921}),
#  Document(page_content='카드설명: 1,500원당 1 대한항공 마일리지 적립, 바우처 서비스 2종 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 922}),
#  Document(page_content='카드설명: 1,500원당 1 대한항공 마일리지 적립, 바우처 서비스 2종 제공, 컨시어지 서비스', metadata={'source': '/workspace/data/tmp.csv', 'row': 923}),
#  Document(page_content='카드설명: 1,500원당 1 대한항공 마일리지 적립, 바우처 서비스 3종 제공, 컨시어지 서비스', metadata={'source': '/workspace/data/tmp.csv', 'row': 924}),
#  Document(page_content='카드설명: 1천원당 최대 2마일리지, 라운지 동반자 혜택, 메탈 플레이트의 품격', metadata={'source': '/workspace/data/tmp.csv', 'row': 925}),
#  Document(page_content='카드설명: 라이프 스타일에 맞게 골라서 사용하는 프리미엄 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 926}),
#  Document(page_content='카드설명: 당신의 서명으로 완성되는 프리미엄 시그니처 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 927}),
#  Document(page_content='카드설명: 실속있게 누리는 프리미엄 라이프', metadata={'source': '/workspace/data/tmp.csv', 'row': 928}),
#  Document(page_content='카드설명: 라이프 스타일에 맞게 골라서 사용하는 프리미엄 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 929}),
#  Document(page_content='카드설명: 당신의 서명으로 완성되는 프리미엄 시그니처 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 930}),
#  Document(page_content='카드설명: 실속있게 누리는 프리미엄 라이프', metadata={'source': '/workspace/data/tmp.csv', 'row': 931}),
#  Document(page_content='카드설명: 라이프 스타일에 맞게 골라서 사용하는 프리미엄 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 932}),
#  Document(page_content='카드설명: YOU DESERVE THE ONE & ONLY - 대한민국 VVIP카드, CLUB1', metadata={'source': '/workspace/data/tmp.csv', 'row': 933}),
#  Document(page_content='카드설명: 대한항공 마일리지 1,500원당 최대 3마일리지 적립, 프리미엄 바우처, 전 세계 라운지 무료 이용', metadata={'source': '/workspace/data/tmp.csv', 'row': 934}),
#  Document(page_content='카드설명: 신세계 백화점 5% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 935}),
#  Document(page_content='카드설명: 원스토어 2% 무제한 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 936}),
#  Document(page_content='카드설명: 언택트 시대에 필요한 맞춤형 카드!', metadata={'source': '/workspace/data/tmp.csv', 'row': 937}),
#  Document(page_content='카드설명: 하나로마트를 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 938}),
#  Document(page_content='카드설명: 풀무원에서 가장 높은 혜택 제공! 월 최대 2만원 할인!', metadata={'source': '/workspace/data/tmp.csv', 'row': 939}),
#  Document(page_content='카드설명: APR 브랜드 월 최대 3만원 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 940}),
#  Document(page_content='카드설명: 자주쓰는 곳에서 하나머니 적립!', metadata={'source': '/workspace/data/tmp.csv', 'row': 941}),
#  Document(page_content='카드설명: 교직원을 위한 특별한 혜택이 담긴 ITIC 국제교사증 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 942}),
#  Document(page_content='카드설명: 실적, 적립한도 제한없이 아시아나 마일리지 the! 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 943}),
#  Document(page_content='카드설명: 공무원을 위한 특별한 혜택이 담긴 공무원 연금 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 944}),
#  Document(page_content='카드설명: 공무원을 위한 특별한 혜택이 담긴 공무원연금 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 945}),
#  Document(page_content='카드설명: 공무원을 위한 특별한 혜택이 담긴 공무원연금 카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 946}),
#  Document(page_content='카드설명: 다양하고 엄선된 컨텐츠 제공 콘텐츠박스 서비스와 1Q 서비스를 하나로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 947}),
#  Document(page_content='카드설명: KT 고객의 라이트 한 삶을 위한 혜택! KT 상품 및 통신요금 청구 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 948}),
#  Document(page_content='카드설명: KT 고객의 Super한 삶을 위한 혜택! KT 통신요금 청구 할인 및 생활서비스를 하나로!', metadata={'source': '/workspace/data/tmp.csv', 'row': 949}),
#  Document(page_content='카드설명: 주유부터 픽업까지! 똑똑한 Car Life를 시작해보세요.', metadata={'source': '/workspace/data/tmp.csv', 'row': 950}),
#  Document(page_content='카드설명: 청호나이스 렌탈을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 951}),
#  Document(page_content='카드설명: 코웨이 렌탈을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 952}),
#  Document(page_content='카드설명: 만삼천원의 행복 바디프랜드 렌탈을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 953}),
#  Document(page_content='카드설명: 만삼천원의 행복 CUCKOO 렌탈을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 954}),
#  Document(page_content='카드설명: 렌탈 자동이체 시 월 8,000원 또는 월 13,000원 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 955}),
#  Document(page_content='카드설명: LG전자 장기할부 및 렌탈료 이용 고객을 위한 특별한 혜택!', metadata={'source': '/workspace/data/tmp.csv', 'row': 956}),
#  Document(page_content='카드설명: 렌탈요금 자동이체 시 13,000원 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 957}),
#  Document(page_content='카드설명: 웰릭스렌탈을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 958}),
#  Document(page_content='카드설명: BS렌탈을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 959}),
#  Document(page_content='카드설명: 실적에서 자유롭고, 혜택을 덤으로 주는 내 지갑 속 카페', metadata={'source': '/workspace/data/tmp.csv', 'row': 960}),
#  Document(page_content='카드설명: 스피킹맥스/ 뇌새김 장기할부 및 할인서비스 제공', metadata={'source': '/workspace/data/tmp.csv', 'row': 961}),
#  Document(page_content='카드설명: 국내 가맹점 0.7%, 국내 온라인/해외 가맹점 1.7% 할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 962}),
#  Document(page_content='카드설명: 건강하게 할인혜택을 챙기는 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 963}),
#  Document(page_content='카드설명: 스마트한 뇌새김 학습에 할인혜택을!', metadata={'source': '/workspace/data/tmp.csv', 'row': 964}),
#  Document(page_content='카드설명: SK매직을 이용하는 현명한 방법!', metadata={'source': '/workspace/data/tmp.csv', 'row': 965}),
#  Document(page_content='카드설명: 토마토 솔루션 가맹점에서 월 최대 5만원 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 966}),
#  Document(page_content='카드설명: 대명아임레디 자동이체 시 최대 19,000원 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 967}),
#  Document(page_content='카드설명: 정직한 신선 유기농 선별샵 프레딧에 할인 혜택을!', metadata={'source': '/workspace/data/tmp.csv', 'row': 968}),
#  Document(page_content='카드설명: 삼프로TV 유료컨텐츠 청구할인', metadata={'source': '/workspace/data/tmp.csv', 'row': 969}),
#  Document(page_content='카드설명: 전월 실적 없이 어디서나 최대 0.4% 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 970}),
#  Document(page_content='카드설명: T1과 FAKER 선수 팬들을 위한 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 971}),
#  Document(page_content='카드설명: 모두의 건강을 선물합니다!', metadata={'source': '/workspace/data/tmp.csv', 'row': 972}),
#  Document(page_content='카드설명: L.PAY 결제로 더 큰 혜택을 누리자!', metadata={'source': '/workspace/data/tmp.csv', 'row': 973}),
#  Document(page_content='카드설명: 신세계 백화점 기본할인에 캐쉬백까지 카드 한장에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 974}),
#  Document(page_content='카드설명: 시코르 기본할인에 캐쉬백까지 카드 한 장에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 975}),
#  Document(page_content='카드설명: 영(Young)한 당신을 위한 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 976}),
#  Document(page_content='카드설명: 영(Young)한 당신을 위한 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 977}),
#  Document(page_content='카드설명: 포인트를 현금처럼 쓰는 하나멤버스 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 978}),
#  Document(page_content='카드설명: HoYoverse 게임을 즐기는 분이라면 누구나', metadata={'source': '/workspace/data/tmp.csv', 'row': 979}),
#  Document(page_content='카드설명: 포인트를 현금처럼 쓰는 하나멤버스 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 980}),
#  Document(page_content='카드설명: CJ ONE 제휴 가맹점에서 더 큰 혜택을 누리자! 모바일과 하나되어 더욱 스마트해진 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 981}),
#  Document(page_content='카드설명: 체크카드 혜택과 해피포인트 멤버쉽 기능을 한번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 982}),
#  Document(page_content='카드설명: 대학생들이 많이 이용하는 곳에서 적립된 포인트로 학자금대출 원리금 상환 가능!', metadata={'source': '/workspace/data/tmp.csv', 'row': 983}),
#  Document(page_content='카드설명: 국민연금 수급자를 위한 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 984}),
#  Document(page_content='카드설명: 청년의 꿈, 새로운 도전', metadata={'source': '/workspace/data/tmp.csv', 'row': 985}),
#  Document(page_content='카드설명: 전월 실적없이 어디서나 하나머니 적립', metadata={'source': '/workspace/data/tmp.csv', 'row': 986}),
#  Document(page_content='카드설명: 영(Young)한 당신과 어울리는 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 987}),
#  Document(page_content='카드설명: 카카오 리틀프렌즈와 함께하는 나의 첫 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 988}),
#  Document(page_content='카드설명: 가장 빠른 모바일 결제 카카오페이와 체크카드의 만남', metadata={'source': '/workspace/data/tmp.csv', 'row': 989}),
#  Document(page_content='카드설명: 넥슨 메이플스토리와 하나카드의 만남', metadata={'source': '/workspace/data/tmp.csv', 'row': 990}),
#  Document(page_content='카드설명: 국가바우처와 임신/출산 진료비 지원을 한번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 991}),
#  Document(page_content='카드설명: 던전앤파이터와 하나카드의 만남', metadata={'source': '/workspace/data/tmp.csv', 'row': 992}),
#  Document(page_content='카드설명: 해외직구 할인과 대중교통 캐쉬백을 한번에!', metadata={'source': '/workspace/data/tmp.csv', 'row': 993}),
#  Document(page_content='카드설명: 세상의 금쪽이들 다 모여라', metadata={'source': '/workspace/data/tmp.csv', 'row': 994}),
#  Document(page_content='카드설명: 실적에 관계없이 제공되는 국내 하나머니 적립혜택해외 18개 통화가 결제되는 해외여행 필수템', metadata={'source': '/workspace/data/tmp.csv', 'row': 995}),
#  Document(page_content='카드설명: 해외 수수료 완전 면제', metadata={'source': '/workspace/data/tmp.csv', 'row': 996}),
#  Document(page_content='카드설명: 국내 5대 업종, 해외쇼핑 캐쉬백 서비스!', metadata={'source': '/workspace/data/tmp.csv', 'row': 997}),
#  Document(page_content='카드설명: 길한통 체크카드 가지고 중국 가세요!연회비 면제! 해외이용수수료 면제!', metadata={'source': '/workspace/data/tmp.csv', 'row': 998}),
#  Document(page_content='카드설명: 안전하고 편리한 해외 전용 외화 체크카드', metadata={'source': '/workspace/data/tmp.csv', 'row': 999}),
#  ...]
